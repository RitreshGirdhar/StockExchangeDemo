# %%
# import libraries
import requests
import json
from dataclasses import dataclass, asdict
from typing import List
import pandas as pd

# %%
# Define models
@dataclass
class Order:
    symbol: str
    qty: int
    side: str
    type: str
    price: float
    time_in_force: str
        
@dataclass
class Trade:
    symbol: str
    qty: int
    price: float
    side: str
    timestamp: str
    order_id: str
    instmt: str
    trade_price: str
    trade_qty: str
    trade_side: str
    trade_id: int
    @classmethod
    def from_dict(cls, data: dict) -> 'Trade':
        return cls(**data)
    
@dataclass
class StockDetails:
    symbol: str
    name: str
    exchange: str
    currency: str
    country: str
    sector: str
    industry: str
    market_cap: float
    beta: float
    pe_ratio: float
    eps: float
    dividend_yield: float
    dividend_per_share: float
    dividend_pay_date: str
    dividend_ex_date: str
    last_split_factor: str
    last_split_date: str    
    @classmethod
    def from_dict(cls, data: dict) -> 'StockDetails':
        return cls(**data)
      
@dataclass
class TopStock:
    symbol: str
    name: str
    change_pct: float
    price: float

# %%
# Define the base URL of the dummy stock exchange API
base_url = 'http://localhost:5000/api/'

# services
def get_stock_detail(symbol)-> StockDetails:
    endpoint = 'v1/stock/'+symbol
    response = requests.get(base_url+ endpoint)
    if response.status_code == 200:
        stock_dict = response.json()
        stock = StockDetails.from_dict(stock_dict)
        return stock
    else:
        raise Exception("Internal server error")
    
def place_order(order) -> Trade:
    endpoint = 'v1/orders/place'
    response = requests.post(base_url + endpoint, json=asdict(order))

    if response.status_code == 200:
        print("Order Placed Successfully")
        respdict = response.json()
        trade = Trade.from_dict(respdict)
        return trade
    else:
        raise Exception("Order was not executed")
        
def cancel_order(order):
    # Define the endpoint for placing an order
    endpoint = 'v1/orders/cancel'
    # Send the request to place the order
    response = requests.delete(base_url + endpoint, json=asdict(order))
    # Print the response
    print(response.status_code)
    
    # Print the trade response
    if response.status_code == 200:
        trade_dict = response.json()['trade']
        print("Order deleted")
    else:
        raise Exception("Order was not cancelled")

# %%
tradersTop10Stocks = ['AAPL','MSFT','GOOG','AMZN','PCAR','TSLA','META']

# %%
# Program should first read the list of instruments (with relevant details) available on the exchange. 
stocks = [get_stock_detail(tradersTop10Stocks[0])]

# %%
from prettytable import PrettyTable

# Assuming you have a list of StockDetails objects called 'stocks'
table = PrettyTable()
table.field_names = ["Symbol", "Name", "Exchange", "Currency", "Country", "Sector", "Industry", "Market Cap", "Beta", "P/E Ratio", "EPS", "Dividend Yield", "Dividend/Share", "Dividend Pay Date", "Dividend Ex Date", "Last Split Factor", "Last Split Date"]

for stock in stocks:
    table.add_row([stock.symbol, stock.name, stock.exchange, stock.currency, stock.country, stock.sector, stock.industry, stock.market_cap, stock.beta, stock.pe_ratio, stock.eps, stock.dividend_yield, stock.dividend_per_share, stock.dividend_pay_date, stock.dividend_ex_date, stock.last_split_factor, stock.last_split_date])

print(table)
# Out:
# +--------+------------+----------+----------+---------+------------+----------------------+------------+------+-----------+------+----------------+----------------+-------------------+------------------+-------------------+-----------------+
# | Symbol |    Name    | Exchange | Currency | Country |   Sector   |       Industry       | Market Cap | Beta | P/E Ratio | EPS  | Dividend Yield | Dividend/Share | Dividend Pay Date | Dividend Ex Date | Last Split Factor | Last Split Date |
# +--------+------------+----------+----------+---------+------------+----------------------+------------+------+-----------+------+----------------+----------------+-------------------+------------------+-------------------+-----------------+
# |  AAPL  | Apple Inc. |  NASDAQ  |   USD    |   USA   | Technology | Consumer Electronics | 2234926.77 | 1.22 |   30.92   | 5.19 |      0.61      |      0.88      |     2023-03-11    |    2023-03-14    |        7:1        |    2023-03-11   |
# +--------+------------+----------+----------+---------+------------+----------------------+------------+------+-----------+------+----------------+----------------+-------------------+------------------+-------------------+-----------------+

# %%
order = Order(symbol='AAPL', qty=100, side='buy', type='limit', price=150.0, time_in_force='gtc')
trade = place_order(order)
# Out:
# Order Placed Successfully

# %%
# Assuming you have a list of StockDetails objects called 'stocks'
table = PrettyTable()
table.field_names = ["Symbol", "Quantity", "Price", "Side", "OrderPlacedAt",
                     "OrderId", "Stock","Trade Price","Trade Quantity","Trade Side","TradeId"]
table.add_row([trade.symbol, trade.qty, trade.price, trade.side, trade.timestamp, trade.order_id, trade.instmt,
               trade.trade_price,  trade.trade_qty,trade.trade_side,trade.trade_id])
print(table)
# Out:
# +--------+----------+-------+------+----------------------------+--------------------------------------+-------+-------------+----------------+------------+--------------------------------------+
# | Symbol | Quantity | Price | Side |       OrderPlacedAt        |               OrderId                | Stock | Trade Price | Trade Quantity | Trade Side |               TradeId                |
# +--------+----------+-------+------+----------------------------+--------------------------------------+-------+-------------+----------------+------------+--------------------------------------+
# |  AAPL  |   100    | 150.0 | buy  | 2023-03-13T04:45:02.157227 | fb2d920f-69d2-48b5-88d8-742682d6ed1a |  AAPL |    150.0    |      100       |    buy     | a6358ca3-38a5-419f-8559-e5d188ad901b |
# +--------+----------+-------+------+----------------------------+--------------------------------------+-------+-------------+----------------+------------+--------------------------------------+

# %% [markdown]
# <h3>Generate orders in bulk</h3>

# %%
import random
import datetime

# Define a list of stocks and their historical prices
stock_prices = {
    'AAPL': [150, 152, 151, 149, 153, 155, 156, 157, 159, 160],
    'GOOG': [1200, 1210, 1220, 1205, 1195, 1185, 1190, 1180, 1175, 1165],
    'TSLA': [700, 710, 720, 730, 735, 740, 745, 750, 755, 760],
    'AMZN': [3000, 3010, 3020, 3015, 3012, 3014, 3018, 3016, 3013, 3011],
    'FB': [350, 355, 360, 365, 370, 375, 380, 385, 390, 395]
}

# Define a list of possible sides
sides = ['BUY', 'SELL']

# Define a list of possible quantities
quantities = list(range(1, 11))

# Define a function to generate a random order
def generate_order():
    # Generate a random stock symbol from the list
    stock = random.choice(list(stock_prices.keys()))

    # Get the last price of the stock
    last_price = stock_prices[stock][-1]

    # Generate a random quantity between 1 and 10
    quantity = random.choice(quantities)

    # Generate a random buy or sell side
    side = random.choice(sides)

    # Generate a realistic price based on the last price of the stock
    if side == 'BUY':
        # Add a random percentage to the last price
        price = round(last_price * (1 + random.uniform(0, 0.05)), 2)
    else:
        # Subtract a random percentage from the last price
        price = round(last_price * (1 - random.uniform(0, 0.05)), 2)

    # Get the current time
    timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    # Create the order dictionary using the randomly generated values
    order = Order(symbol=f'{stock}', qty=quantity, side=f'{side}', type='limit', price=price, time_in_force=timestamp)  
    return order

# Generate 100 random orders
for i in range(100):
    # Generate a random order
    order = generate_order()
    # Print the order statement
    print(f"Randomly generated order statement {i+1}: {order}")    
    trade = place_order(order)
    print(trade)
# Out:
# Randomly generated order statement 1: Order(symbol='AAPL', qty=8, side='SELL', type='limit', price=154.51, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=8, price=154.51, side='SELL', timestamp='2023-03-13T04:50:12.128211', order_id='eaeaf653-8fc9-4737-8cf0-e2f8a856feb1', instmt='AAPL', trade_price=154.51, trade_qty=8, trade_side='SELL', trade_id='e65a057e-22cd-4a49-b23f-1e176d9171b5')
# Randomly generated order statement 2: Order(symbol='AAPL', qty=1, side='BUY', type='limit', price=162.41, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=162.41, side='BUY', timestamp='2023-03-13T04:50:12.134204', order_id='a0df3137-f3db-47bc-9712-c308c81b1881', instmt='AAPL', trade_price=162.41, trade_qty=1, trade_side='BUY', trade_id='65506e8e-71d2-4cdb-9424-d356f4146f0f')
# Randomly generated order statement 3: Order(symbol='TSLA', qty=6, side='SELL', type='limit', price=752.62, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=6, price=752.62, side='SELL', timestamp='2023-03-13T04:50:12.141911', order_id='d569892b-1bd5-4bb7-979a-52b286c53c7d', instmt='TSLA', trade_price=752.62, trade_qty=6, trade_side='SELL', trade_id='153a20bc-81de-4c7a-9efb-21fc51d635f7')
# Randomly generated order statement 4: Order(symbol='TSLA', qty=10, side='BUY', type='limit', price=783.14, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=10, price=783.14, side='BUY', timestamp='2023-03-13T04:50:12.148235', order_id='ad1adcdc-b0eb-4f9e-b434-58aaa8cea56f', instmt='TSLA', trade_price=783.14, trade_qty=10, trade_side='BUY', trade_id='06ad7236-9515-4ff5-9e2a-0cd41a492201')
# Randomly generated order statement 5: Order(symbol='AAPL', qty=6, side='SELL', type='limit', price=154.71, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=6, price=154.71, side='SELL', timestamp='2023-03-13T04:50:12.153049', order_id='b0d63868-b760-47c8-88ca-93a9908fc69e', instmt='AAPL', trade_price=154.71, trade_qty=6, trade_side='SELL', trade_id='c8904950-3f10-43ba-93b7-79e3908f1270')
# Randomly generated order statement 6: Order(symbol='AMZN', qty=5, side='SELL', type='limit', price=3006.29, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=5, price=3006.29, side='SELL', timestamp='2023-03-13T04:50:12.157819', order_id='6a300ba2-0da0-4e1a-848a-06895add84db', instmt='AMZN', trade_price=3006.29, trade_qty=5, trade_side='SELL', trade_id='afd2e7dd-4840-497f-b49a-382270ed856b')
# Randomly generated order statement 7: Order(symbol='GOOG', qty=9, side='BUY', type='limit', price=1219.31, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=9, price=1219.31, side='BUY', timestamp='2023-03-13T04:50:12.162628', order_id='e2c0f630-e845-4e80-a513-a04180314c3c', instmt='GOOG', trade_price=1219.31, trade_qty=9, trade_side='BUY', trade_id='15480b14-dc9e-4acf-bac6-7deac343f9bd')
# Randomly generated order statement 8: Order(symbol='AMZN', qty=1, side='BUY', type='limit', price=3113.45, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=3113.45, side='BUY', timestamp='2023-03-13T04:50:12.168697', order_id='55b39ecb-5e04-4c1d-a4ab-9a36142a1d61', instmt='AMZN', trade_price=3113.45, trade_qty=1, trade_side='BUY', trade_id='2a21c811-4c7a-47a1-8bdf-53b45479cfcd')
# Randomly generated order statement 9: Order(symbol='AAPL', qty=3, side='BUY', type='limit', price=161.97, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=3, price=161.97, side='BUY', timestamp='2023-03-13T04:50:12.174197', order_id='f0bda459-9632-4c1b-a2f6-a682af6e8dca', instmt='AAPL', trade_price=161.97, trade_qty=3, trade_side='BUY', trade_id='6fd7f4ee-7cd2-415c-88de-3acbbbe599c2')
# Randomly generated order statement 10: Order(symbol='GOOG', qty=4, side='SELL', type='limit', price=1141.77, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=4, price=1141.77, side='SELL', timestamp='2023-03-13T04:50:12.179242', order_id='861da00a-d792-41a4-a1e0-ee42923f6234', instmt='GOOG', trade_price=1141.77, trade_qty=4, trade_side='SELL', trade_id='8170797a-d150-4b16-b06f-6946140b3134')
# Randomly generated order statement 11: Order(symbol='AAPL', qty=9, side='BUY', type='limit', price=166.14, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=9, price=166.14, side='BUY', timestamp='2023-03-13T04:50:12.184814', order_id='cb1c8ec6-9677-48f7-bd2e-96f762094d15', instmt='AAPL', trade_price=166.14, trade_qty=9, trade_side='BUY', trade_id='46a67289-be04-4f95-ba2d-8be2beac89d7')
# Randomly generated order statement 12: Order(symbol='GOOG', qty=1, side='BUY', type='limit', price=1219.84, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=1, price=1219.84, side='BUY', timestamp='2023-03-13T04:50:12.190823', order_id='c9e9cf1f-2dfc-4ec3-bcb6-326e60b4a5f5', instmt='GOOG', trade_price=1219.84, trade_qty=1, trade_side='BUY', trade_id='7fc2b625-d0a0-47ee-b142-56007125a405')
# Randomly generated order statement 13: Order(symbol='GOOG', qty=8, side='SELL', type='limit', price=1132.7, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=8, price=1132.7, side='SELL', timestamp='2023-03-13T04:50:12.197912', order_id='5148f4c7-2bf9-4ed5-94ec-ab8272ce2658', instmt='GOOG', trade_price=1132.7, trade_qty=8, trade_side='SELL', trade_id='c5895819-cf2c-4fad-be4c-551445b96871')
# Randomly generated order statement 14: Order(symbol='TSLA', qty=2, side='BUY', type='limit', price=784.2, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=2, price=784.2, side='BUY', timestamp='2023-03-13T04:50:12.203574', order_id='15408917-441d-41d2-907e-516251c66eed', instmt='TSLA', trade_price=784.2, trade_qty=2, trade_side='BUY', trade_id='e16fa30a-88c7-4dc6-b35a-807bdf2f4c4b')
# Randomly generated order statement 15: Order(symbol='TSLA', qty=1, side='SELL', type='limit', price=726.44, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=1, price=726.44, side='SELL', timestamp='2023-03-13T04:50:12.209510', order_id='dc5931f9-820d-4b75-96c8-a9fda5a3af7b', instmt='TSLA', trade_price=726.44, trade_qty=1, trade_side='SELL', trade_id='cb01f748-44b4-45be-84eb-23bf2f8498f6')
# Randomly generated order statement 16: Order(symbol='FB', qty=6, side='SELL', type='limit', price=385.81, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=6, price=385.81, side='SELL', timestamp='2023-03-13T04:50:12.215685', order_id='dbd5fa8a-60ff-42c4-b7c3-6adaefa11d67', instmt='FB', trade_price=385.81, trade_qty=6, trade_side='SELL', trade_id='47f3657c-370a-4447-a3a4-8ba8cf7fdc11')
# Randomly generated order statement 17: Order(symbol='TSLA', qty=9, side='SELL', type='limit', price=754.65, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=9, price=754.65, side='SELL', timestamp='2023-03-13T04:50:12.220373', order_id='08278683-12a8-42c2-ba6c-54e2e8400018', instmt='TSLA', trade_price=754.65, trade_qty=9, trade_side='SELL', trade_id='a62aab34-d24a-4b03-96bc-7ef7cf2b3c0e')
# Randomly generated order statement 18: Order(symbol='AMZN', qty=5, side='BUY', type='limit', price=3113.73, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=5, price=3113.73, side='BUY', timestamp='2023-03-13T04:50:12.225739', order_id='1d5ddfe0-3380-4c89-b726-f7a930e9396c', instmt='AMZN', trade_price=3113.73, trade_qty=5, trade_side='BUY', trade_id='cfe98538-ed19-4b99-b8c8-9e30c4ed76e7')
# Randomly generated order statement 19: Order(symbol='GOOG', qty=10, side='BUY', type='limit', price=1179.94, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1179.94, side='BUY', timestamp='2023-03-13T04:50:12.230685', order_id='9e669b7a-ee4c-4a49-ba73-3185fdb28476', instmt='GOOG', trade_price=1179.94, trade_qty=10, trade_side='BUY', trade_id='06161e06-f418-4cd6-b8cc-36b08e4658a0')
# Randomly generated order statement 20: Order(symbol='TSLA', qty=1, side='BUY', type='limit', price=774.65, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=1, price=774.65, side='BUY', timestamp='2023-03-13T04:50:12.236601', order_id='8b7bd715-cc26-4df7-b072-6043c895d62a', instmt='TSLA', trade_price=774.65, trade_qty=1, trade_side='BUY', trade_id='cc697800-ab48-4240-9fd5-070e663a4a66')
# Randomly generated order statement 21: Order(symbol='AAPL', qty=1, side='BUY', type='limit', price=164.58, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=164.58, side='BUY', timestamp='2023-03-13T04:50:12.241680', order_id='9e7ad47d-d064-4439-9b41-bb195fdf30ec', instmt='AAPL', trade_price=164.58, trade_qty=1, trade_side='BUY', trade_id='2c9b4ea4-8efe-4330-884d-af5c8a3d107a')
# Randomly generated order statement 22: Order(symbol='FB', qty=4, side='SELL', type='limit', price=378.79, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=4, price=378.79, side='SELL', timestamp='2023-03-13T04:50:12.246704', order_id='784ac169-4ef5-4ef9-a337-917d7404fd83', instmt='FB', trade_price=378.79, trade_qty=4, trade_side='SELL', trade_id='c26cad6b-b8d0-4432-afc5-881d035d79c9')
# Randomly generated order statement 23: Order(symbol='FB', qty=1, side='BUY', type='limit', price=397.36, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=1, price=397.36, side='BUY', timestamp='2023-03-13T04:50:12.250851', order_id='70ce3365-bf37-4bfb-894c-ca139332f426', instmt='FB', trade_price=397.36, trade_qty=1, trade_side='BUY', trade_id='cf1d7167-b90b-4252-8580-39cf5366405e')
# Randomly generated order statement 24: Order(symbol='GOOG', qty=6, side='BUY', type='limit', price=1216.81, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=6, price=1216.81, side='BUY', timestamp='2023-03-13T04:50:12.255289', order_id='88a94965-4ccd-44a0-a95f-e1897cbf963a', instmt='GOOG', trade_price=1216.81, trade_qty=6, trade_side='BUY', trade_id='64359f92-10f1-42c7-abb7-21f5c03818e6')
# Randomly generated order statement 25: Order(symbol='FB', qty=4, side='SELL', type='limit', price=389.49, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=4, price=389.49, side='SELL', timestamp='2023-03-13T04:50:12.260826', order_id='fa898e74-7095-4987-b4fb-6550aed1d9a9', instmt='FB', trade_price=389.49, trade_qty=4, trade_side='SELL', trade_id='e0c9a9ce-3d4f-4d9d-baa6-c08ccfd14220')
# Randomly generated order statement 26: Order(symbol='AMZN', qty=1, side='SELL', type='limit', price=3007.07, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=3007.07, side='SELL', timestamp='2023-03-13T04:50:12.266097', order_id='68af692a-66ec-474b-8784-0def616236dd', instmt='AMZN', trade_price=3007.07, trade_qty=1, trade_side='SELL', trade_id='f7697a0d-e594-401d-89c4-33054229c928')
# Randomly generated order statement 27: Order(symbol='TSLA', qty=10, side='SELL', type='limit', price=732.45, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=10, price=732.45, side='SELL', timestamp='2023-03-13T04:50:12.270716', order_id='0690e7fa-4e0b-4d06-a94b-1ce17e0c3ea0', instmt='TSLA', trade_price=732.45, trade_qty=10, trade_side='SELL', trade_id='ad610568-c64e-4df8-914b-138603319bc1')
# Randomly generated order statement 28: Order(symbol='GOOG', qty=3, side='BUY', type='limit', price=1179.75, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1179.75, side='BUY', timestamp='2023-03-13T04:50:12.275130', order_id='64bce1fc-8209-40a1-9f0a-6ab8c7c0ebd8', instmt='GOOG', trade_price=1179.75, trade_qty=3, trade_side='BUY', trade_id='93b251ac-2958-46b7-aa47-6160a2d77388')
# Randomly generated order statement 29: Order(symbol='FB', qty=1, side='SELL', type='limit', price=383.44, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=1, price=383.44, side='SELL', timestamp='2023-03-13T04:50:12.278865', order_id='28711621-8c3d-4e5c-9614-71469ae1677d', instmt='FB', trade_price=383.44, trade_qty=1, trade_side='SELL', trade_id='fd711420-8fcd-4e63-ae96-eb2f415e7060')
# Randomly generated order statement 30: Order(symbol='AMZN', qty=10, side='SELL', type='limit', price=2923.67, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=10, price=2923.67, side='SELL', timestamp='2023-03-13T04:50:12.282108', order_id='b022ce27-73cd-42b6-888c-3ddf6265e207', instmt='AMZN', trade_price=2923.67, trade_qty=10, trade_side='SELL', trade_id='b4954039-cbfa-4895-8637-3ef3e0be8feb')
# Randomly generated order statement 31: Order(symbol='AAPL', qty=3, side='SELL', type='limit', price=156.45, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=3, price=156.45, side='SELL', timestamp='2023-03-13T04:50:12.286402', order_id='78dcec14-9b05-4f8c-8d9b-954947bf9bff', instmt='AAPL', trade_price=156.45, trade_qty=3, trade_side='SELL', trade_id='a3ccb48c-884e-4f4c-aa0e-d20796c6f5e9')
# Randomly generated order statement 32: Order(symbol='AAPL', qty=2, side='BUY', type='limit', price=160.42, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=160.42, side='BUY', timestamp='2023-03-13T04:50:12.291810', order_id='ded6f67c-c54a-4398-bfe2-76962dd9f453', instmt='AAPL', trade_price=160.42, trade_qty=2, trade_side='BUY', trade_id='2aa1c2fd-f264-4da5-84aa-6763a207b5a2')
# Randomly generated order statement 33: Order(symbol='TSLA', qty=6, side='BUY', type='limit', price=760.25, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=6, price=760.25, side='BUY', timestamp='2023-03-13T04:50:12.299619', order_id='facb99a8-8221-4319-82ae-06655e751c02', instmt='TSLA', trade_price=760.25, trade_qty=6, trade_side='BUY', trade_id='e68d49c1-3a60-4cdc-8fb3-9d52b6e25b34')
# Randomly generated order statement 34: Order(symbol='AAPL', qty=2, side='SELL', type='limit', price=160.0, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=160.0, side='SELL', timestamp='2023-03-13T04:50:12.304887', order_id='d81abbcf-ec4d-466e-abb5-86c5f5677a1e', instmt='AAPL', trade_price=160.0, trade_qty=2, trade_side='SELL', trade_id='e4978b56-dd8a-4884-aff8-08c7ff341ab8')
# Randomly generated order statement 35: Order(symbol='AMZN', qty=1, side='SELL', type='limit', price=2911.62, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=2911.62, side='SELL', timestamp='2023-03-13T04:50:12.309659', order_id='a17ef5e6-2c51-4ea7-8a7d-fa795a243ec2', instmt='AMZN', trade_price=2911.62, trade_qty=1, trade_side='SELL', trade_id='d39ce9ce-700f-410e-9c82-3e20d7765e6b')
# Randomly generated order statement 36: Order(symbol='FB', qty=10, side='BUY', type='limit', price=401.16, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=401.16, side='BUY', timestamp='2023-03-13T04:50:12.314469', order_id='6c2de036-88ac-4c26-aa22-e28b34618988', instmt='FB', trade_price=401.16, trade_qty=10, trade_side='BUY', trade_id='176970dc-d37e-41db-a064-6bbd5aa67dc3')
# Randomly generated order statement 37: Order(symbol='GOOG', qty=6, side='SELL', type='limit', price=1146.5, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=6, price=1146.5, side='SELL', timestamp='2023-03-13T04:50:12.319369', order_id='8281f3b5-9d0c-4721-b7ba-82590eafdba3', instmt='GOOG', trade_price=1146.5, trade_qty=6, trade_side='SELL', trade_id='490e6711-eb88-4c64-8d36-565ef7ad466e')
# Randomly generated order statement 38: Order(symbol='AAPL', qty=9, side='SELL', type='limit', price=153.49, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=9, price=153.49, side='SELL', timestamp='2023-03-13T04:50:12.323698', order_id='787d3c04-52b2-4f8b-bb83-d9373d785034', instmt='AAPL', trade_price=153.49, trade_qty=9, trade_side='SELL', trade_id='ce4ac357-c412-4265-b1d0-cac1c1e3513a')
# Randomly generated order statement 39: Order(symbol='AAPL', qty=4, side='BUY', type='limit', price=165.22, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=4, price=165.22, side='BUY', timestamp='2023-03-13T04:50:12.329305', order_id='4d59a3d6-a1b8-4cd5-a531-49de69492b25', instmt='AAPL', trade_price=165.22, trade_qty=4, trade_side='BUY', trade_id='99363707-b3ae-402e-8dde-9bb45ff79b40')
# Randomly generated order statement 40: Order(symbol='FB', qty=5, side='SELL', type='limit', price=386.73, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=5, price=386.73, side='SELL', timestamp='2023-03-13T04:50:12.334031', order_id='26966d11-a6ca-4f1c-a355-ce0a9da817ab', instmt='FB', trade_price=386.73, trade_qty=5, trade_side='SELL', trade_id='617a03b8-11e1-41dc-ac97-d7fc998b4932')
# Randomly generated order statement 41: Order(symbol='FB', qty=3, side='BUY', type='limit', price=396.68, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=3, price=396.68, side='BUY', timestamp='2023-03-13T04:50:12.340855', order_id='95186860-15b0-4eca-a4fc-a910d3393de4', instmt='FB', trade_price=396.68, trade_qty=3, trade_side='BUY', trade_id='d5eefc2c-f0ec-44e0-a8ba-9f2aa659c205')
# Randomly generated order statement 42: Order(symbol='FB', qty=10, side='BUY', type='limit', price=412.08, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=412.08, side='BUY', timestamp='2023-03-13T04:50:12.351477', order_id='e7bc1a3d-978e-4f57-87cc-af12aa32d379', instmt='FB', trade_price=412.08, trade_qty=10, trade_side='BUY', trade_id='c42dd191-72e4-4b5d-8525-48e8dc56738e')
# Randomly generated order statement 43: Order(symbol='AAPL', qty=4, side='SELL', type='limit', price=156.46, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=4, price=156.46, side='SELL', timestamp='2023-03-13T04:50:12.358974', order_id='f16796d3-b849-4e73-94e0-aa1432984be5', instmt='AAPL', trade_price=156.46, trade_qty=4, trade_side='SELL', trade_id='fb6c78e6-a2d6-4aef-8bae-7516114c161a')
# Randomly generated order statement 44: Order(symbol='AMZN', qty=5, side='BUY', type='limit', price=3120.52, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=5, price=3120.52, side='BUY', timestamp='2023-03-13T04:50:12.367498', order_id='4aa23448-a283-46ed-a09f-8bda13ec272c', instmt='AMZN', trade_price=3120.52, trade_qty=5, trade_side='BUY', trade_id='cf6c5616-b4ec-408b-94e9-7eae37c3ab69')
# Randomly generated order statement 45: Order(symbol='GOOG', qty=10, side='BUY', type='limit', price=1213.89, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1213.89, side='BUY', timestamp='2023-03-13T04:50:12.372703', order_id='61128bbb-9be3-4416-9dd0-98564adeb1b1', instmt='GOOG', trade_price=1213.89, trade_qty=10, trade_side='BUY', trade_id='ebce672c-3c31-44b4-b025-804461333d68')
# Randomly generated order statement 46: Order(symbol='GOOG', qty=9, side='BUY', type='limit', price=1223.08, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=9, price=1223.08, side='BUY', timestamp='2023-03-13T04:50:12.378311', order_id='40db9349-1cce-4d09-b5cd-f6ffe18fa98a', instmt='GOOG', trade_price=1223.08, trade_qty=9, trade_side='BUY', trade_id='d5eb8419-30dd-45dd-bd0e-d658c28c7efd')
# Randomly generated order statement 47: Order(symbol='AMZN', qty=6, side='BUY', type='limit', price=3148.3, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=6, price=3148.3, side='BUY', timestamp='2023-03-13T04:50:12.385468', order_id='d47c0a06-0967-4a26-8883-071bad767aa0', instmt='AMZN', trade_price=3148.3, trade_qty=6, trade_side='BUY', trade_id='901948fb-a320-495e-9e21-62392825e3df')
# Randomly generated order statement 48: Order(symbol='TSLA', qty=6, side='SELL', type='limit', price=745.55, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=6, price=745.55, side='SELL', timestamp='2023-03-13T04:50:12.390915', order_id='8070b6fa-ebc4-425e-8f29-36ee515b94c6', instmt='TSLA', trade_price=745.55, trade_qty=6, trade_side='SELL', trade_id='fc6bb4f5-a692-4a9e-9e7f-9dc9506da89c')
# Randomly generated order statement 49: Order(symbol='TSLA', qty=9, side='SELL', type='limit', price=726.73, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=9, price=726.73, side='SELL', timestamp='2023-03-13T04:50:12.396407', order_id='068524e1-7020-4588-a100-19d420dc9d68', instmt='TSLA', trade_price=726.73, trade_qty=9, trade_side='SELL', trade_id='6a13a2b7-077f-474e-9350-04e69993266d')
# Randomly generated order statement 50: Order(symbol='TSLA', qty=9, side='BUY', type='limit', price=785.21, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=9, price=785.21, side='BUY', timestamp='2023-03-13T04:50:12.401412', order_id='a7c0c060-305c-4839-b16c-91c58287c8e3', instmt='TSLA', trade_price=785.21, trade_qty=9, trade_side='BUY', trade_id='fbb5d578-feb6-4a7e-8bbf-1cebbdbcf025')
# Randomly generated order statement 51: Order(symbol='AMZN', qty=2, side='SELL', type='limit', price=2963.01, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=2, price=2963.01, side='SELL', timestamp='2023-03-13T04:50:12.407512', order_id='e8988476-b156-4f9e-8da5-c05a9a0b0fdf', instmt='AMZN', trade_price=2963.01, trade_qty=2, trade_side='SELL', trade_id='52058df6-4df8-4a82-b1f0-fae4df163bcb')
# Randomly generated order statement 52: Order(symbol='GOOG', qty=10, side='BUY', type='limit', price=1193.91, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1193.91, side='BUY', timestamp='2023-03-13T04:50:12.413387', order_id='02e65796-d311-4e2a-a78f-28a0bc7495ed', instmt='GOOG', trade_price=1193.91, trade_qty=10, trade_side='BUY', trade_id='b8d1ceb8-8226-453f-bd92-61bdb2683a01')
# Randomly generated order statement 53: Order(symbol='AAPL', qty=6, side='SELL', type='limit', price=155.52, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=6, price=155.52, side='SELL', timestamp='2023-03-13T04:50:12.418743', order_id='62a5e6a0-05c2-4bea-a87c-7a19b35103ba', instmt='AAPL', trade_price=155.52, trade_qty=6, trade_side='SELL', trade_id='c573ff0b-9727-47cb-a523-74f828c5af39')
# Randomly generated order statement 54: Order(symbol='FB', qty=10, side='SELL', type='limit', price=391.12, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=391.12, side='SELL', timestamp='2023-03-13T04:50:12.424047', order_id='f31d0af8-4cb2-447e-8a3d-9a0f72da8a49', instmt='FB', trade_price=391.12, trade_qty=10, trade_side='SELL', trade_id='5231ce8a-0dca-484e-ab4f-70e30ca7f683')
# Randomly generated order statement 55: Order(symbol='GOOG', qty=5, side='BUY', type='limit', price=1202.98, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=5, price=1202.98, side='BUY', timestamp='2023-03-13T04:50:12.429844', order_id='8684f547-03c8-4d31-9251-69ae39fa3316', instmt='GOOG', trade_price=1202.98, trade_qty=5, trade_side='BUY', trade_id='990d9679-1bbf-4c42-a112-ce1a60f44289')
# Randomly generated order statement 56: Order(symbol='TSLA', qty=8, side='BUY', type='limit', price=765.63, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=8, price=765.63, side='BUY', timestamp='2023-03-13T04:50:12.435308', order_id='f0b312e1-4007-46e9-ade3-867c05f84ae9', instmt='TSLA', trade_price=765.63, trade_qty=8, trade_side='BUY', trade_id='b4b3107c-4185-4911-9657-a7b9116bafba')
# Randomly generated order statement 57: Order(symbol='TSLA', qty=7, side='SELL', type='limit', price=744.92, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=7, price=744.92, side='SELL', timestamp='2023-03-13T04:50:12.440300', order_id='1ffa17fc-09be-4214-a52f-c1f0046e6f2b', instmt='TSLA', trade_price=744.92, trade_qty=7, trade_side='SELL', trade_id='cb44188b-6ba8-438f-b381-440488c22ee6')
# Randomly generated order statement 58: Order(symbol='AMZN', qty=2, side='SELL', type='limit', price=2894.17, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=2, price=2894.17, side='SELL', timestamp='2023-03-13T04:50:12.446168', order_id='e00d6221-2022-4c5b-8f72-8eb6e7daa543', instmt='AMZN', trade_price=2894.17, trade_qty=2, trade_side='SELL', trade_id='26512f81-d5c5-4555-9480-be0e8395c564')
# Randomly generated order statement 59: Order(symbol='GOOG', qty=10, side='SELL', type='limit', price=1117.81, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1117.81, side='SELL', timestamp='2023-03-13T04:50:12.454343', order_id='920ba1e8-e4bf-49a7-abc4-184727973c4c', instmt='GOOG', trade_price=1117.81, trade_qty=10, trade_side='SELL', trade_id='97a6fb25-6f76-4b45-9f8d-a0007d2924c6')
# Randomly generated order statement 60: Order(symbol='AMZN', qty=8, side='SELL', type='limit', price=2878.81, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=8, price=2878.81, side='SELL', timestamp='2023-03-13T04:50:12.463316', order_id='d2d63db1-0fe6-486c-9c31-71e9a84647c8', instmt='AMZN', trade_price=2878.81, trade_qty=8, trade_side='SELL', trade_id='7d19cfbb-bc8d-438d-9b71-08aa56beaae5')
# Randomly generated order statement 61: Order(symbol='AAPL', qty=10, side='BUY', type='limit', price=161.85, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=10, price=161.85, side='BUY', timestamp='2023-03-13T04:50:12.471354', order_id='c7352130-374c-4592-ac07-8a06b137548f', instmt='AAPL', trade_price=161.85, trade_qty=10, trade_side='BUY', trade_id='427f2169-87b4-4084-8b6c-0ec69732e05c')
# Randomly generated order statement 62: Order(symbol='AAPL', qty=7, side='BUY', type='limit', price=164.36, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=7, price=164.36, side='BUY', timestamp='2023-03-13T04:50:12.479483', order_id='37ce39b1-4b9d-4dad-8889-070b91846278', instmt='AAPL', trade_price=164.36, trade_qty=7, trade_side='BUY', trade_id='a8ffe183-7755-46e2-869f-2bffe3521cac')
# Randomly generated order statement 63: Order(symbol='GOOG', qty=1, side='SELL', type='limit', price=1114.25, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=1, price=1114.25, side='SELL', timestamp='2023-03-13T04:50:12.487803', order_id='79829184-a712-4c14-a04f-3773432a8313', instmt='GOOG', trade_price=1114.25, trade_qty=1, trade_side='SELL', trade_id='1224c488-acef-4db3-ba45-a6da4f02048a')
# Randomly generated order statement 64: Order(symbol='AMZN', qty=1, side='SELL', type='limit', price=2951.72, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=2951.72, side='SELL', timestamp='2023-03-13T04:50:12.493836', order_id='43d98b01-1b5e-424e-96dd-c1b5db450bdd', instmt='AMZN', trade_price=2951.72, trade_qty=1, trade_side='SELL', trade_id='2927d616-5fa7-4b72-a521-9f91837f498d')
# Randomly generated order statement 65: Order(symbol='FB', qty=6, side='BUY', type='limit', price=410.25, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=6, price=410.25, side='BUY', timestamp='2023-03-13T04:50:12.498580', order_id='5b3ff296-53d5-457a-afc8-a52a1e84dac3', instmt='FB', trade_price=410.25, trade_qty=6, trade_side='BUY', trade_id='0ce9fc37-1fc4-4968-8ebf-1bfe548f102e')
# Randomly generated order statement 66: Order(symbol='GOOG', qty=3, side='BUY', type='limit', price=1183.97, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1183.97, side='BUY', timestamp='2023-03-13T04:50:12.502979', order_id='774e8c10-a904-4518-b98a-e82438d01d35', instmt='GOOG', trade_price=1183.97, trade_qty=3, trade_side='BUY', trade_id='35cbe5bd-56dd-41ca-a337-c8b67d7c1fc0')
# Randomly generated order statement 67: Order(symbol='AMZN', qty=3, side='BUY', type='limit', price=3134.2, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=3, price=3134.2, side='BUY', timestamp='2023-03-13T04:50:12.508061', order_id='372c695b-4709-491a-bbdf-c57f2d6e36ea', instmt='AMZN', trade_price=3134.2, trade_qty=3, trade_side='BUY', trade_id='17783677-86d7-4985-b4ab-89831fa746fe')
# Randomly generated order statement 68: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1152.16, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1152.16, side='SELL', timestamp='2023-03-13T04:50:12.513461', order_id='15eb1cf7-e65a-4b01-b90f-773e4f89281c', instmt='GOOG', trade_price=1152.16, trade_qty=7, trade_side='SELL', trade_id='3f801d5e-d3e9-4fe0-95e9-9065830a8607')
# Randomly generated order statement 69: Order(symbol='AMZN', qty=3, side='BUY', type='limit', price=3052.9, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=3, price=3052.9, side='BUY', timestamp='2023-03-13T04:50:12.519041', order_id='90dc8b42-9e4e-415c-9670-eaa9fae1e3ef', instmt='AMZN', trade_price=3052.9, trade_qty=3, trade_side='BUY', trade_id='f116207b-9673-48c7-b349-38abd1144ee1')
# Randomly generated order statement 70: Order(symbol='TSLA', qty=1, side='SELL', type='limit', price=744.05, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=1, price=744.05, side='SELL', timestamp='2023-03-13T04:50:12.524284', order_id='bb2083b0-c1e7-4bea-8718-1da9cf92c813', instmt='TSLA', trade_price=744.05, trade_qty=1, trade_side='SELL', trade_id='4e2bb60e-c200-4419-b307-d31eace59b40')
# Randomly generated order statement 71: Order(symbol='GOOG', qty=3, side='SELL', type='limit', price=1128.23, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1128.23, side='SELL', timestamp='2023-03-13T04:50:12.529521', order_id='b543376b-d2f9-4f5b-9f62-536a0bbe0d52', instmt='GOOG', trade_price=1128.23, trade_qty=3, trade_side='SELL', trade_id='bbd12619-0a3a-4174-a2ab-a35dd46db5db')
# Randomly generated order statement 72: Order(symbol='AAPL', qty=7, side='SELL', type='limit', price=156.45, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=7, price=156.45, side='SELL', timestamp='2023-03-13T04:50:12.535691', order_id='76860d99-370b-4621-a0c6-0254982ea78f', instmt='AAPL', trade_price=156.45, trade_qty=7, trade_side='SELL', trade_id='7227cc68-c8d1-4462-bef6-cc1e0ee92eb3')
# Randomly generated order statement 73: Order(symbol='TSLA', qty=4, side='BUY', type='limit', price=771.15, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=4, price=771.15, side='BUY', timestamp='2023-03-13T04:50:12.541750', order_id='60398162-86ed-401f-a382-b2e3cf33645d', instmt='TSLA', trade_price=771.15, trade_qty=4, trade_side='BUY', trade_id='4528506f-363a-4cd0-8e6c-ba21f87694b3')
# Randomly generated order statement 74: Order(symbol='FB', qty=5, side='BUY', type='limit', price=399.98, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=5, price=399.98, side='BUY', timestamp='2023-03-13T04:50:12.547033', order_id='78f88f84-3fc3-4bc4-b1e0-38879de87480', instmt='FB', trade_price=399.98, trade_qty=5, trade_side='BUY', trade_id='4e709d1d-8019-49eb-9687-76c9d0055b43')
# Randomly generated order statement 75: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1149.65, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1149.65, side='SELL', timestamp='2023-03-13T04:50:12.554836', order_id='1b1e5793-affa-426e-9866-d042efdc5549', instmt='GOOG', trade_price=1149.65, trade_qty=7, trade_side='SELL', trade_id='f5ea741c-9da2-44bb-95a4-5306e3ac9d21')
# Randomly generated order statement 76: Order(symbol='GOOG', qty=4, side='BUY', type='limit', price=1181.1, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=4, price=1181.1, side='BUY', timestamp='2023-03-13T04:50:12.566425', order_id='63fc2eda-7fa1-4093-bfb9-fc3cbdc3232a', instmt='GOOG', trade_price=1181.1, trade_qty=4, trade_side='BUY', trade_id='5605f45b-ed3d-4fdf-8e74-db9ad3824b60')
# Randomly generated order statement 77: Order(symbol='FB', qty=10, side='SELL', type='limit', price=382.25, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=382.25, side='SELL', timestamp='2023-03-13T04:50:12.575565', order_id='59e4159c-0492-4ccb-82f6-1a0175a6816a', instmt='FB', trade_price=382.25, trade_qty=10, trade_side='SELL', trade_id='b97548d3-c28d-4134-a6c4-45f81e936aab')
# Randomly generated order statement 78: Order(symbol='FB', qty=8, side='SELL', type='limit', price=382.3, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=8, price=382.3, side='SELL', timestamp='2023-03-13T04:50:12.581595', order_id='74c71dd6-107e-4281-a572-c4101b28bb9f', instmt='FB', trade_price=382.3, trade_qty=8, trade_side='SELL', trade_id='2e4eafe9-c88e-4cc8-a240-a4c80d92ba0f')
# Randomly generated order statement 79: Order(symbol='AAPL', qty=2, side='SELL', type='limit', price=157.6, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=157.6, side='SELL', timestamp='2023-03-13T04:50:12.586870', order_id='defcd6a4-1963-40c5-a079-283c12b72e67', instmt='AAPL', trade_price=157.6, trade_qty=2, trade_side='SELL', trade_id='cd297266-d60c-4de6-a309-9277ab599dcd')
# Randomly generated order statement 80: Order(symbol='FB', qty=10, side='SELL', type='limit', price=381.58, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=381.58, side='SELL', timestamp='2023-03-13T04:50:12.594051', order_id='e046d0e1-fbfa-4140-a9c4-8fd4b5fd0fe9', instmt='FB', trade_price=381.58, trade_qty=10, trade_side='SELL', trade_id='16b79c90-aead-4b46-a86c-4f60bd02af13')
# Randomly generated order statement 81: Order(symbol='TSLA', qty=1, side='SELL', type='limit', price=758.19, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=1, price=758.19, side='SELL', timestamp='2023-03-13T04:50:12.602096', order_id='e505999b-22c5-4502-bdf3-1e01f00d8cf7', instmt='TSLA', trade_price=758.19, trade_qty=1, trade_side='SELL', trade_id='bedbf226-7878-45bb-aa3f-ba224f96f125')
# Randomly generated order statement 82: Order(symbol='GOOG', qty=4, side='BUY', type='limit', price=1174.81, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=4, price=1174.81, side='BUY', timestamp='2023-03-13T04:50:12.607413', order_id='6ee7d091-caac-40d3-b054-e3cba3a97e50', instmt='GOOG', trade_price=1174.81, trade_qty=4, trade_side='BUY', trade_id='7228713c-af94-4985-a222-bce802e19ab2')
# Randomly generated order statement 83: Order(symbol='GOOG', qty=10, side='SELL', type='limit', price=1134.96, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1134.96, side='SELL', timestamp='2023-03-13T04:50:12.613383', order_id='ba54f608-c1f1-4b76-bef9-e5d39298c164', instmt='GOOG', trade_price=1134.96, trade_qty=10, trade_side='SELL', trade_id='b186a020-67d0-409f-b6d1-ab21a21a2e2e')
# Randomly generated order statement 84: Order(symbol='FB', qty=10, side='BUY', type='limit', price=396.54, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=396.54, side='BUY', timestamp='2023-03-13T04:50:12.618833', order_id='bd191526-4882-4273-9f26-bc272a24628d', instmt='FB', trade_price=396.54, trade_qty=10, trade_side='BUY', trade_id='a8692a97-5ad0-4162-869a-54cca8421f2c')
# Randomly generated order statement 85: Order(symbol='FB', qty=5, side='BUY', type='limit', price=400.19, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=5, price=400.19, side='BUY', timestamp='2023-03-13T04:50:12.624316', order_id='913142b2-d1e2-416b-89ea-326e82e56916', instmt='FB', trade_price=400.19, trade_qty=5, trade_side='BUY', trade_id='db3a92f6-bc0a-4bc3-b793-e4cc0ddf72c3')
# Randomly generated order statement 86: Order(symbol='GOOG', qty=8, side='BUY', type='limit', price=1217.23, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=8, price=1217.23, side='BUY', timestamp='2023-03-13T04:50:12.629031', order_id='cc27dc40-d3c3-43f9-a3d5-01e7a77ac34d', instmt='GOOG', trade_price=1217.23, trade_qty=8, trade_side='BUY', trade_id='1d63cd68-d552-42a2-b0c1-7a637e715fd6')
# Randomly generated order statement 87: Order(symbol='AMZN', qty=1, side='BUY', type='limit', price=3123.84, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=3123.84, side='BUY', timestamp='2023-03-13T04:50:12.634312', order_id='aed09866-3329-457e-9cf5-f15b9c80aae9', instmt='AMZN', trade_price=3123.84, trade_qty=1, trade_side='BUY', trade_id='136cef35-737b-4a3b-8d2a-64f6ca5f0ff1')
# Randomly generated order statement 88: Order(symbol='AMZN', qty=2, side='BUY', type='limit', price=3038.56, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=2, price=3038.56, side='BUY', timestamp='2023-03-13T04:50:12.639523', order_id='8d4ff5f3-ad24-42c2-bc90-5e0d2cf41eb7', instmt='AMZN', trade_price=3038.56, trade_qty=2, trade_side='BUY', trade_id='c73b8e54-efe8-479b-9aff-a96bfc07b614')
# Randomly generated order statement 89: Order(symbol='FB', qty=2, side='BUY', type='limit', price=401.32, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=2, price=401.32, side='BUY', timestamp='2023-03-13T04:50:12.648502', order_id='de39e964-7435-4c94-a1b5-0f1966a79daf', instmt='FB', trade_price=401.32, trade_qty=2, trade_side='BUY', trade_id='accf8777-b5ff-4a53-8b40-ff89129f0320')
# Randomly generated order statement 90: Order(symbol='FB', qty=6, side='BUY', type='limit', price=404.45, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=6, price=404.45, side='BUY', timestamp='2023-03-13T04:50:12.655317', order_id='85f1104e-7492-4a3b-99aa-a93ea961d7eb', instmt='FB', trade_price=404.45, trade_qty=6, trade_side='BUY', trade_id='1e7b3f38-9eb5-41ed-b859-dbfee5b5df23')
# Randomly generated order statement 91: Order(symbol='AAPL', qty=10, side='BUY', type='limit', price=163.04, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=10, price=163.04, side='BUY', timestamp='2023-03-13T04:50:12.660894', order_id='11aaeb2b-8562-4262-b97b-65595284940c', instmt='AAPL', trade_price=163.04, trade_qty=10, trade_side='BUY', trade_id='0778e43c-4bb2-47f2-93e4-26be8c246281')
# Randomly generated order statement 92: Order(symbol='FB', qty=10, side='SELL', type='limit', price=390.22, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=390.22, side='SELL', timestamp='2023-03-13T04:50:12.665162', order_id='68103d93-894d-4c76-b266-eccccf70b820', instmt='FB', trade_price=390.22, trade_qty=10, trade_side='SELL', trade_id='41447fb5-884e-4ac0-97d7-6e112530985e')
# Randomly generated order statement 93: Order(symbol='FB', qty=3, side='BUY', type='limit', price=408.14, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=3, price=408.14, side='BUY', timestamp='2023-03-13T04:50:12.670526', order_id='bf2baf33-7329-4214-9ace-c91e67f7882f', instmt='FB', trade_price=408.14, trade_qty=3, trade_side='BUY', trade_id='4e15af85-bfed-44c4-a0a4-d08df8b15721')
# Randomly generated order statement 94: Order(symbol='GOOG', qty=4, side='SELL', type='limit', price=1152.41, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=4, price=1152.41, side='SELL', timestamp='2023-03-13T04:50:12.678867', order_id='27b3d16f-116f-4fc3-81c5-52b2a9a7fc40', instmt='GOOG', trade_price=1152.41, trade_qty=4, trade_side='SELL', trade_id='0b9b59dd-f08c-4cfb-82ee-699e05e7cd09')
# Randomly generated order statement 95: Order(symbol='FB', qty=7, side='SELL', type='limit', price=387.93, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=7, price=387.93, side='SELL', timestamp='2023-03-13T04:50:12.687054', order_id='c92873a1-0e58-4928-b765-6a4bb4f6ad07', instmt='FB', trade_price=387.93, trade_qty=7, trade_side='SELL', trade_id='f0bd1473-bd3a-4106-9007-8bab12bae945')
# Randomly generated order statement 96: Order(symbol='TSLA', qty=5, side='SELL', type='limit', price=752.88, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=5, price=752.88, side='SELL', timestamp='2023-03-13T04:50:12.695159', order_id='53a195de-8dfe-42d8-b5cb-101c688ad492', instmt='TSLA', trade_price=752.88, trade_qty=5, trade_side='SELL', trade_id='5855996c-e41a-43fb-9444-ca047130dbe0')
# Randomly generated order statement 97: Order(symbol='TSLA', qty=3, side='BUY', type='limit', price=766.76, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=3, price=766.76, side='BUY', timestamp='2023-03-13T04:50:12.702210', order_id='19afb95f-6630-4b4f-a0f8-c1254a925e1c', instmt='TSLA', trade_price=766.76, trade_qty=3, trade_side='BUY', trade_id='5f20fe1e-3744-4bb0-ab63-c72bc4747259')
# Randomly generated order statement 98: Order(symbol='AAPL', qty=8, side='BUY', type='limit', price=160.17, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=8, price=160.17, side='BUY', timestamp='2023-03-13T04:50:12.708920', order_id='e45d7e81-53c1-41a2-a984-441aa83df65d', instmt='AAPL', trade_price=160.17, trade_qty=8, trade_side='BUY', trade_id='5dbc3518-00fe-443e-b9a0-ed7dd3b16925')
# Randomly generated order statement 99: Order(symbol='AAPL', qty=2, side='SELL', type='limit', price=154.86, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=154.86, side='SELL', timestamp='2023-03-13T04:50:12.714708', order_id='b8d91fb9-e7f1-4dfd-abba-b5c643919fc8', instmt='AAPL', trade_price=154.86, trade_qty=2, trade_side='SELL', trade_id='cca4b76d-88a8-4acb-8c89-a9dbc90ec567')
# Randomly generated order statement 100: Order(symbol='FB', qty=2, side='BUY', type='limit', price=410.65, time_in_force='2023-03-13 00:50:12')
# Order Placed Successfully
# Trade(symbol='FB', qty=2, price=410.65, side='BUY', timestamp='2023-03-13T04:50:12.720987', order_id='8f372a41-38c1-42b2-9f5c-a7e506144d76', instmt='FB', trade_price=410.65, trade_qty=2, trade_side='BUY', trade_id='aa3b0bb5-43a1-49f0-bc7e-123b1e4e3c47')
