# %%
# import libraries
import requests
import json
from dataclasses import dataclass, asdict
from typing import List
import pandas as pd

# %%
# Define models
@dataclass
class Order:
    symbol: str
    qty: int
    side: str
    type: str
    price: float
    time_in_force: str
        
@dataclass
class Trade:
    symbol: str
    qty: int
    price: float
    side: str
    timestamp: str
    order_id: str
    instmt: str
    trade_price: str
    trade_qty: str
    trade_side: str
    trade_id: int
    @classmethod
    def from_dict(cls, data: dict) -> 'Trade':
        return cls(**data)
    
@dataclass
class StockDetails:
    symbol: str
    name: str
    exchange: str
    currency: str
    country: str
    sector: str
    industry: str
    market_cap: float
    beta: float
    pe_ratio: float
    eps: float
    dividend_yield: float
    dividend_per_share: float
    dividend_pay_date: str
    dividend_ex_date: str
    last_split_factor: str
    last_split_date: str    
    @classmethod
    def from_dict(cls, data: dict) -> 'StockDetails':
        return cls(**data)
      
@dataclass
class TopStock:
    symbol: str
    name: str
    change_pct: float
    price: float

# %%
# Define the base URL of the dummy stock exchange API
base_url = 'http://localhost:5000/api/'

# services
def get_stock_detail(symbol)-> StockDetails:
    endpoint = 'v1/stock/'+symbol
    response = requests.get(base_url+ endpoint)
    if response.status_code == 200:
        stock_dict = response.json()
        stock = StockDetails.from_dict(stock_dict)
        return stock
    else:
        raise Exception("Internal server error")
    
def place_order(order) -> Trade:
    endpoint = 'v1/orders/place'
    response = requests.post(base_url + endpoint, json=asdict(order))

    if response.status_code == 200:
        print("Order Placed Successfully")
        respdict = response.json()
        trade = Trade.from_dict(respdict)
        return trade
    else:
        raise Exception("Order was not executed")
        
def cancel_order(order):
    # Define the endpoint for placing an order
    endpoint = 'v1/orders/cancel'
    # Send the request to place the order
    response = requests.delete(base_url + endpoint, json=asdict(order))
    # Print the response
    print(response.status_code)
    
    # Print the trade response
    if response.status_code == 200:
        trade_dict = response.json()['trade']
        print("Order deleted")
    else:
        raise Exception("Order was not cancelled")

# %%
tradersTop10Stocks = ['AAPL','MSFT','GOOG','AMZN','PCAR','TSLA','META']

# %%
# Program should first read the list of instruments (with relevant details) available on the exchange. 
stocks = [get_stock_detail(tradersTop10Stocks[0])]

# %%
from prettytable import PrettyTable

# Assuming you have a list of StockDetails objects called 'stocks'
table = PrettyTable()
table.field_names = ["Symbol", "Name", "Exchange", "Currency", "Country", "Sector", "Industry", "Market Cap", "Beta", "P/E Ratio", "EPS", "Dividend Yield", "Dividend/Share", "Dividend Pay Date", "Dividend Ex Date", "Last Split Factor", "Last Split Date"]

for stock in stocks:
    table.add_row([stock.symbol, stock.name, stock.exchange, stock.currency, stock.country, stock.sector, stock.industry, stock.market_cap, stock.beta, stock.pe_ratio, stock.eps, stock.dividend_yield, stock.dividend_per_share, stock.dividend_pay_date, stock.dividend_ex_date, stock.last_split_factor, stock.last_split_date])

print(table)
# Out:
# +--------+------------+----------+----------+---------+------------+----------------------+------------+------+-----------+------+----------------+----------------+-------------------+------------------+-------------------+-----------------+
# | Symbol |    Name    | Exchange | Currency | Country |   Sector   |       Industry       | Market Cap | Beta | P/E Ratio | EPS  | Dividend Yield | Dividend/Share | Dividend Pay Date | Dividend Ex Date | Last Split Factor | Last Split Date |
# +--------+------------+----------+----------+---------+------------+----------------------+------------+------+-----------+------+----------------+----------------+-------------------+------------------+-------------------+-----------------+
# |  AAPL  | Apple Inc. |  NASDAQ  |   USD    |   USA   | Technology | Consumer Electronics | 2234926.77 | 1.22 |   30.92   | 5.19 |      0.61      |      0.88      |     2023-03-11    |    2023-03-14    |        7:1        |    2023-03-11   |
# +--------+------------+----------+----------+---------+------------+----------------------+------------+------+-----------+------+----------------+----------------+-------------------+------------------+-------------------+-----------------+

# %%
order = Order(symbol='AAPL', qty=100, side='buy', type='limit', price=150.0, time_in_force='gtc')
trade = place_order(order)
# Out:
# Order Placed Successfully

# %%
# Assuming you have a list of StockDetails objects called 'stocks'
table = PrettyTable()
table.field_names = ["Symbol", "Quantity", "Price", "Side", "OrderPlacedAt",
                     "OrderId", "Stock","Trade Price","Trade Quantity","Trade Side","TradeId"]
table.add_row([trade.symbol, trade.qty, trade.price, trade.side, trade.timestamp, trade.order_id, trade.instmt,
               trade.trade_price,  trade.trade_qty,trade.trade_side,trade.trade_id])
print(table)
# Out:
# +--------+----------+-------+------+----------------------------+--------------------------------------+-------+-------------+----------------+------------+--------------------------------------+
# | Symbol | Quantity | Price | Side |       OrderPlacedAt        |               OrderId                | Stock | Trade Price | Trade Quantity | Trade Side |               TradeId                |
# +--------+----------+-------+------+----------------------------+--------------------------------------+-------+-------------+----------------+------------+--------------------------------------+
# |  AAPL  |   100    | 150.0 | buy  | 2023-03-11T20:22:07.495652 | bf53bc72-2f20-4853-bd8d-98e3047cb3b8 |  AAPL |    150.0    |      100       |    buy     | d91bbef2-0128-4ee1-9e31-fc7dfb618043 |
# +--------+----------+-------+------+----------------------------+--------------------------------------+-------+-------------+----------------+------------+--------------------------------------+

# %% [markdown]
# <h3>Generate orders in bulk</h3>

# %%
import random
import datetime

# Define a list of stocks and their historical prices
stock_prices = {
    'AAPL': [150, 152, 151, 149, 153, 155, 156, 157, 159, 160],
    'GOOG': [1200, 1210, 1220, 1205, 1195, 1185, 1190, 1180, 1175, 1165],
    'TSLA': [700, 710, 720, 730, 735, 740, 745, 750, 755, 760],
    'AMZN': [3000, 3010, 3020, 3015, 3012, 3014, 3018, 3016, 3013, 3011],
    'FB': [350, 355, 360, 365, 370, 375, 380, 385, 390, 395]
}

# Define a list of possible sides
sides = ['BUY', 'SELL']

# Define a list of possible quantities
quantities = list(range(1, 11))

# Define a function to generate a random order
def generate_order():
    # Generate a random stock symbol from the list
    stock = random.choice(list(stock_prices.keys()))

    # Get the last price of the stock
    last_price = stock_prices[stock][-1]

    # Generate a random quantity between 1 and 10
    quantity = random.choice(quantities)

    # Generate a random buy or sell side
    side = random.choice(sides)

    # Generate a realistic price based on the last price of the stock
    if side == 'BUY':
        # Add a random percentage to the last price
        price = round(last_price * (1 + random.uniform(0, 0.05)), 2)
    else:
        # Subtract a random percentage from the last price
        price = round(last_price * (1 - random.uniform(0, 0.05)), 2)

    # Get the current time
    timestamp = datetime.datetime.now().strftime('%Y-%m-%d %H:%M:%S')

    # Create the order dictionary using the randomly generated values
    order = Order(symbol=f'{stock}', qty=quantity, side=f'{side}', type='limit', price=price, time_in_force=timestamp)  
    return order

# Generate 100 random orders
for i in range(100):
    # Generate a random order
    order = generate_order()
    # Print the order statement
    print(f"Randomly generated order statement {i+1}: {order}")    
    trade = place_order(order)
    print(trade)
# Out:
# Randomly generated order statement 1: Order(symbol='AAPL', qty=1, side='BUY', type='limit', price=161.64, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=161.64, side='BUY', timestamp='2023-03-11T21:41:33.132123', order_id='c9c91173-52da-4c08-bd9d-49a8a9d47284', instmt='AAPL', trade_price=161.64, trade_qty=1, trade_side='BUY', trade_id='ec8c8333-2cd3-49c0-a1a0-bfb3d4eda140')
# Randomly generated order statement 2: Order(symbol='TSLA', qty=8, side='BUY', type='limit', price=788.93, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=8, price=788.93, side='BUY', timestamp='2023-03-11T21:41:33.137705', order_id='fd79b46f-72df-4fc2-9c2d-65422f16a2d7', instmt='TSLA', trade_price=788.93, trade_qty=8, trade_side='BUY', trade_id='aa389ff0-86c0-41b5-8af8-0c7f65ebe817')
# Randomly generated order statement 3: Order(symbol='GOOG', qty=9, side='BUY', type='limit', price=1209.62, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=9, price=1209.62, side='BUY', timestamp='2023-03-11T21:41:33.142467', order_id='38bf40ec-8721-48ac-a744-b9d021f6ce4c', instmt='GOOG', trade_price=1209.62, trade_qty=9, trade_side='BUY', trade_id='cdb94ed3-a83e-4e52-bdc5-c188d4fae416')
# Randomly generated order statement 4: Order(symbol='GOOG', qty=3, side='SELL', type='limit', price=1110.11, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1110.11, side='SELL', timestamp='2023-03-11T21:41:33.147125', order_id='19f480ab-bf17-4fb0-904a-05e7578256f5', instmt='GOOG', trade_price=1110.11, trade_qty=3, trade_side='SELL', trade_id='ab927747-68fe-464d-93fd-c1bc20abaebe')
# Randomly generated order statement 5: Order(symbol='FB', qty=9, side='BUY', type='limit', price=404.57, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=9, price=404.57, side='BUY', timestamp='2023-03-11T21:41:33.151392', order_id='6ed59781-c44d-4785-ad6d-6f9163ea49b5', instmt='FB', trade_price=404.57, trade_qty=9, trade_side='BUY', trade_id='3e147f11-a9e7-4dd7-a20b-42b1a2bcd449')
# Randomly generated order statement 6: Order(symbol='AAPL', qty=6, side='BUY', type='limit', price=161.62, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=6, price=161.62, side='BUY', timestamp='2023-03-11T21:41:33.155553', order_id='2de1a0cd-cdce-4de9-9df0-5f3930c6e302', instmt='AAPL', trade_price=161.62, trade_qty=6, trade_side='BUY', trade_id='c8d698d9-995d-46a1-bd64-19f18efc288a')
# Randomly generated order statement 7: Order(symbol='AMZN', qty=10, side='SELL', type='limit', price=2999.14, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=10, price=2999.14, side='SELL', timestamp='2023-03-11T21:41:33.159819', order_id='90bd8503-1370-4893-87b8-70c46bbe9823', instmt='AMZN', trade_price=2999.14, trade_qty=10, trade_side='SELL', trade_id='de4a389e-7310-46ae-b684-9526d02c6feb')
# Randomly generated order statement 8: Order(symbol='TSLA', qty=3, side='SELL', type='limit', price=733.18, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=3, price=733.18, side='SELL', timestamp='2023-03-11T21:41:33.164292', order_id='b5e04c7f-5a95-41bb-94cc-2aa19bbbd24d', instmt='TSLA', trade_price=733.18, trade_qty=3, trade_side='SELL', trade_id='fe59fe1d-90b6-45e8-b869-608c502b9632')
# Randomly generated order statement 9: Order(symbol='AMZN', qty=3, side='SELL', type='limit', price=2974.6, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=3, price=2974.6, side='SELL', timestamp='2023-03-11T21:41:33.168948', order_id='10871352-2718-47e9-a2ff-b4c15134f318', instmt='AMZN', trade_price=2974.6, trade_qty=3, trade_side='SELL', trade_id='ce71d67e-933e-4a41-af7b-776c7cb8821e')
# Randomly generated order statement 10: Order(symbol='AMZN', qty=3, side='BUY', type='limit', price=3110.15, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=3, price=3110.15, side='BUY', timestamp='2023-03-11T21:41:33.173217', order_id='263c3671-f001-4622-a960-5d158b801829', instmt='AMZN', trade_price=3110.15, trade_qty=3, trade_side='BUY', trade_id='2700dc8e-28dd-48eb-97ae-5fc9c9238345')
# Randomly generated order statement 11: Order(symbol='AMZN', qty=8, side='SELL', type='limit', price=2933.77, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=8, price=2933.77, side='SELL', timestamp='2023-03-11T21:41:33.178054', order_id='219d6422-b1d7-429d-8056-6fe898e19e51', instmt='AMZN', trade_price=2933.77, trade_qty=8, trade_side='SELL', trade_id='22bff611-315c-4c63-a6a6-7d339633d88a')
# Randomly generated order statement 12: Order(symbol='FB', qty=5, side='SELL', type='limit', price=392.01, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=5, price=392.01, side='SELL', timestamp='2023-03-11T21:41:33.182650', order_id='23b274c0-1ad2-4dd4-8add-842382d29e7f', instmt='FB', trade_price=392.01, trade_qty=5, trade_side='SELL', trade_id='2a97c66e-949f-4154-abc1-a728e2fc3098')
# Randomly generated order statement 13: Order(symbol='AMZN', qty=6, side='BUY', type='limit', price=3113.74, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=6, price=3113.74, side='BUY', timestamp='2023-03-11T21:41:33.188176', order_id='114e89d9-a9f3-44f2-9680-50db618c3c0a', instmt='AMZN', trade_price=3113.74, trade_qty=6, trade_side='BUY', trade_id='a375bbf9-be3e-462d-b168-7d4ae17640ef')
# Randomly generated order statement 14: Order(symbol='AAPL', qty=4, side='BUY', type='limit', price=160.57, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=4, price=160.57, side='BUY', timestamp='2023-03-11T21:41:33.192778', order_id='a72cd572-94ac-46c4-8467-321fb91a10aa', instmt='AAPL', trade_price=160.57, trade_qty=4, trade_side='BUY', trade_id='d6c89f74-bea0-484d-8b3f-a9bcda6387e1')
# Randomly generated order statement 15: Order(symbol='GOOG', qty=7, side='BUY', type='limit', price=1215.33, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1215.33, side='BUY', timestamp='2023-03-11T21:41:33.196511', order_id='0d9847b5-aacb-4728-9325-aa15b027906e', instmt='GOOG', trade_price=1215.33, trade_qty=7, trade_side='BUY', trade_id='1b065733-4190-4d25-9881-85a205b68180')
# Randomly generated order statement 16: Order(symbol='GOOG', qty=10, side='BUY', type='limit', price=1197.83, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1197.83, side='BUY', timestamp='2023-03-11T21:41:33.200589', order_id='8267d371-2cb0-4ade-b908-5b9e71a8af08', instmt='GOOG', trade_price=1197.83, trade_qty=10, trade_side='BUY', trade_id='daf2724a-89f1-4fe3-8283-e59854039274')
# Randomly generated order statement 17: Order(symbol='FB', qty=5, side='SELL', type='limit', price=384.87, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=5, price=384.87, side='SELL', timestamp='2023-03-11T21:41:33.204198', order_id='233e77cc-6223-4652-b7e4-8106c846b913', instmt='FB', trade_price=384.87, trade_qty=5, trade_side='SELL', trade_id='2aa5a53b-9f2e-467f-8253-791e7f5bccd2')
# Randomly generated order statement 18: Order(symbol='AMZN', qty=4, side='BUY', type='limit', price=3065.1, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=4, price=3065.1, side='BUY', timestamp='2023-03-11T21:41:33.208614', order_id='a37f3459-ccf5-49af-8acc-3553794fb3c4', instmt='AMZN', trade_price=3065.1, trade_qty=4, trade_side='BUY', trade_id='575329ea-1cd8-4323-8081-ed52c4191e0d')
# Randomly generated order statement 19: Order(symbol='AAPL', qty=4, side='BUY', type='limit', price=167.62, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=4, price=167.62, side='BUY', timestamp='2023-03-11T21:41:33.213007', order_id='33bcf86a-c8a3-4e4b-b8b7-8bac7485398d', instmt='AAPL', trade_price=167.62, trade_qty=4, trade_side='BUY', trade_id='989cdc21-dea0-4f53-9193-fc4190654e22')
# Randomly generated order statement 20: Order(symbol='AAPL', qty=2, side='BUY', type='limit', price=160.11, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=160.11, side='BUY', timestamp='2023-03-11T21:41:33.217131', order_id='90c09414-cbda-4df7-92c1-bc950adb7933', instmt='AAPL', trade_price=160.11, trade_qty=2, trade_side='BUY', trade_id='38816415-7f71-4e64-89bb-6baab8cc84ab')
# Randomly generated order statement 21: Order(symbol='AMZN', qty=2, side='BUY', type='limit', price=3133.4, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=2, price=3133.4, side='BUY', timestamp='2023-03-11T21:41:33.221070', order_id='df6730b7-6de0-4922-9ad6-f598effd8e9d', instmt='AMZN', trade_price=3133.4, trade_qty=2, trade_side='BUY', trade_id='ddc3f939-66cc-41d5-9f05-a761ad69b8a0')
# Randomly generated order statement 22: Order(symbol='FB', qty=9, side='BUY', type='limit', price=402.13, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=9, price=402.13, side='BUY', timestamp='2023-03-11T21:41:33.225336', order_id='936767f9-69d9-4b2b-8e14-6e68b452ba72', instmt='FB', trade_price=402.13, trade_qty=9, trade_side='BUY', trade_id='84d37878-d044-42df-a138-233667725fc8')
# Randomly generated order statement 23: Order(symbol='TSLA', qty=2, side='SELL', type='limit', price=738.93, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=2, price=738.93, side='SELL', timestamp='2023-03-11T21:41:33.229428', order_id='4eca9424-3db5-438f-b30a-a35e96a07c0e', instmt='TSLA', trade_price=738.93, trade_qty=2, trade_side='SELL', trade_id='4760a80e-0a7d-4025-a5e1-9c21563f0bb3')
# Randomly generated order statement 24: Order(symbol='FB', qty=10, side='BUY', type='limit', price=397.24, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=397.24, side='BUY', timestamp='2023-03-11T21:41:33.233133', order_id='07172c47-6ca1-4c0b-bd4f-fc209fb4088a', instmt='FB', trade_price=397.24, trade_qty=10, trade_side='BUY', trade_id='9cb9b330-4033-406d-81c3-b9b1b566e7a0')
# Randomly generated order statement 25: Order(symbol='FB', qty=9, side='SELL', type='limit', price=378.37, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=9, price=378.37, side='SELL', timestamp='2023-03-11T21:41:33.237255', order_id='9005c25a-fa92-4545-96cb-917dec5d2e58', instmt='FB', trade_price=378.37, trade_qty=9, trade_side='SELL', trade_id='2590ee62-2503-426d-9463-c45e4ba2f7a9')
# Randomly generated order statement 26: Order(symbol='AAPL', qty=2, side='SELL', type='limit', price=154.4, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=154.4, side='SELL', timestamp='2023-03-11T21:41:33.241250', order_id='9dcc176c-4474-4175-9c4b-5b0bf77c616f', instmt='AAPL', trade_price=154.4, trade_qty=2, trade_side='SELL', trade_id='8b48420b-d70a-4f0d-b680-a3f86a22565e')
# Randomly generated order statement 27: Order(symbol='GOOG', qty=6, side='SELL', type='limit', price=1111.38, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=6, price=1111.38, side='SELL', timestamp='2023-03-11T21:41:33.245041', order_id='be4e6d9c-9762-4593-a059-9066b6fd052f', instmt='GOOG', trade_price=1111.38, trade_qty=6, trade_side='SELL', trade_id='e7cadf37-2115-4517-809b-205bc0683d55')
# Randomly generated order statement 28: Order(symbol='GOOG', qty=10, side='BUY', type='limit', price=1194.01, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=10, price=1194.01, side='BUY', timestamp='2023-03-11T21:41:33.248919', order_id='28390294-33f1-4067-af38-5ac5c345293d', instmt='GOOG', trade_price=1194.01, trade_qty=10, trade_side='BUY', trade_id='166e97df-e70b-454d-bf1d-26d63d014c05')
# Randomly generated order statement 29: Order(symbol='AAPL', qty=1, side='SELL', type='limit', price=153.36, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=153.36, side='SELL', timestamp='2023-03-11T21:41:33.252685', order_id='9c4f67b1-cba3-4ab2-b349-513285145a87', instmt='AAPL', trade_price=153.36, trade_qty=1, trade_side='SELL', trade_id='621f201e-7ba4-4fe2-9c67-9d84590c854e')
# Randomly generated order statement 30: Order(symbol='FB', qty=4, side='BUY', type='limit', price=399.91, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=4, price=399.91, side='BUY', timestamp='2023-03-11T21:41:33.256883', order_id='80aceb8a-4e84-4b82-8bdf-7450d88de418', instmt='FB', trade_price=399.91, trade_qty=4, trade_side='BUY', trade_id='c7457e6a-db83-47bd-b705-9356a981eea6')
# Randomly generated order statement 31: Order(symbol='FB', qty=3, side='SELL', type='limit', price=387.07, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=3, price=387.07, side='SELL', timestamp='2023-03-11T21:41:33.260928', order_id='daeb21e2-56e5-4d33-bf08-0c5832f2c9ee', instmt='FB', trade_price=387.07, trade_qty=3, trade_side='SELL', trade_id='1e13821e-0364-4670-8108-a3bcb2b24d0a')
# Randomly generated order statement 32: Order(symbol='AAPL', qty=8, side='SELL', type='limit', price=156.64, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=8, price=156.64, side='SELL', timestamp='2023-03-11T21:41:33.264851', order_id='2bf479f8-9815-4864-af8a-a6538b1e8063', instmt='AAPL', trade_price=156.64, trade_qty=8, trade_side='SELL', trade_id='44228a26-23c3-4935-bcd5-74b3ac86ad1d')
# Randomly generated order statement 33: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1112.96, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1112.96, side='SELL', timestamp='2023-03-11T21:41:33.268555', order_id='41f01cb5-c0c6-443c-8d8d-ecdd50d3e005', instmt='GOOG', trade_price=1112.96, trade_qty=7, trade_side='SELL', trade_id='d59950ef-ed9f-4395-a257-4a72ed796d18')
# Randomly generated order statement 34: Order(symbol='AAPL', qty=6, side='SELL', type='limit', price=155.04, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=6, price=155.04, side='SELL', timestamp='2023-03-11T21:41:33.272501', order_id='163cec61-f079-40b8-9df2-71c72185d172', instmt='AAPL', trade_price=155.04, trade_qty=6, trade_side='SELL', trade_id='2e766934-eff0-4fae-9d43-da8e625c2885')
# Randomly generated order statement 35: Order(symbol='FB', qty=4, side='SELL', type='limit', price=383.61, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=4, price=383.61, side='SELL', timestamp='2023-03-11T21:41:33.277040', order_id='c1eb9d84-07f2-49f7-aca3-d607ca1ef7b1', instmt='FB', trade_price=383.61, trade_qty=4, trade_side='SELL', trade_id='7938c562-3a4c-4234-8753-8e73e1553d32')
# Randomly generated order statement 36: Order(symbol='AMZN', qty=6, side='SELL', type='limit', price=2934.8, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=6, price=2934.8, side='SELL', timestamp='2023-03-11T21:41:33.281388', order_id='73ec9cd4-3510-485c-ab1a-25590bd5cd41', instmt='AMZN', trade_price=2934.8, trade_qty=6, trade_side='SELL', trade_id='0a8ee798-99a8-4d15-9742-c53766885ba6')
# Randomly generated order statement 37: Order(symbol='GOOG', qty=9, side='SELL', type='limit', price=1114.95, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=9, price=1114.95, side='SELL', timestamp='2023-03-11T21:41:33.285538', order_id='3728dece-74e8-4b2b-b7c9-ab3616d55d71', instmt='GOOG', trade_price=1114.95, trade_qty=9, trade_side='SELL', trade_id='f2a78271-263a-4662-82d5-c97ecd9bb788')
# Randomly generated order statement 38: Order(symbol='FB', qty=9, side='BUY', type='limit', price=412.59, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=9, price=412.59, side='BUY', timestamp='2023-03-11T21:41:33.289862', order_id='57c5fa6b-98cc-45dc-9545-9bfc6683030f', instmt='FB', trade_price=412.59, trade_qty=9, trade_side='BUY', trade_id='e068bb9b-c370-4dd4-b5e2-2cd65abffebf')
# Randomly generated order statement 39: Order(symbol='TSLA', qty=9, side='BUY', type='limit', price=763.93, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=9, price=763.93, side='BUY', timestamp='2023-03-11T21:41:33.294078', order_id='97ac3204-9f79-445d-9d3b-779aca3e932b', instmt='TSLA', trade_price=763.93, trade_qty=9, trade_side='BUY', trade_id='271434b7-09aa-40c9-9e80-c348ad33eff9')
# Randomly generated order statement 40: Order(symbol='GOOG', qty=9, side='BUY', type='limit', price=1179.57, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=9, price=1179.57, side='BUY', timestamp='2023-03-11T21:41:33.298276', order_id='f24c59a7-3c92-48c4-b57e-f4275d677e1c', instmt='GOOG', trade_price=1179.57, trade_qty=9, trade_side='BUY', trade_id='0edfa6ea-341d-4e10-a162-f2d2904dddc5')
# Randomly generated order statement 41: Order(symbol='FB', qty=7, side='SELL', type='limit', price=394.88, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=7, price=394.88, side='SELL', timestamp='2023-03-11T21:41:33.302995', order_id='e0be08a8-dc1d-4202-8822-a339912ba434', instmt='FB', trade_price=394.88, trade_qty=7, trade_side='SELL', trade_id='41145a3c-c2b3-40dc-a068-edf30571e16f')
# Randomly generated order statement 42: Order(symbol='AAPL', qty=2, side='BUY', type='limit', price=167.44, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=167.44, side='BUY', timestamp='2023-03-11T21:41:33.306898', order_id='d8c0c9c9-b128-479e-a259-3180b0924763', instmt='AAPL', trade_price=167.44, trade_qty=2, trade_side='BUY', trade_id='63df0677-c0bf-462d-aa67-023e2e57ab49')
# Randomly generated order statement 43: Order(symbol='FB', qty=2, side='SELL', type='limit', price=392.6, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=2, price=392.6, side='SELL', timestamp='2023-03-11T21:41:33.310712', order_id='029f84ab-fa48-4fbb-a201-89425bb3b557', instmt='FB', trade_price=392.6, trade_qty=2, trade_side='SELL', trade_id='ba859908-278b-4bec-918b-ce07c59adb20')
# Randomly generated order statement 44: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1146.91, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1146.91, side='SELL', timestamp='2023-03-11T21:41:33.314412', order_id='4d720a85-e457-4b49-ab51-cb45086c57d2', instmt='GOOG', trade_price=1146.91, trade_qty=7, trade_side='SELL', trade_id='bf13d55b-3db4-4247-956c-699bc5a7c459')
# Randomly generated order statement 45: Order(symbol='FB', qty=3, side='BUY', type='limit', price=397.77, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=3, price=397.77, side='BUY', timestamp='2023-03-11T21:41:33.317923', order_id='cffee192-3786-477b-a0ae-fe917f0e4b84', instmt='FB', trade_price=397.77, trade_qty=3, trade_side='BUY', trade_id='3afa2b3f-24fc-4c96-bc31-e65d24a9d6aa')
# Randomly generated order statement 46: Order(symbol='FB', qty=2, side='SELL', type='limit', price=392.46, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=2, price=392.46, side='SELL', timestamp='2023-03-11T21:41:33.322269', order_id='378cde68-688c-4071-9b5c-2c240eec1cf6', instmt='FB', trade_price=392.46, trade_qty=2, trade_side='SELL', trade_id='1d22e619-0a43-4ca0-bd0c-5db874eba237')
# Randomly generated order statement 47: Order(symbol='GOOG', qty=9, side='BUY', type='limit', price=1203.26, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=9, price=1203.26, side='BUY', timestamp='2023-03-11T21:41:33.325791', order_id='4241de45-d740-4b70-a2a0-6c3e87500993', instmt='GOOG', trade_price=1203.26, trade_qty=9, trade_side='BUY', trade_id='79d27a0f-3e02-4067-afa0-fdd17f1dbb8b')
# Randomly generated order statement 48: Order(symbol='GOOG', qty=3, side='SELL', type='limit', price=1136.69, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1136.69, side='SELL', timestamp='2023-03-11T21:41:33.329628', order_id='2bb0f5f7-1ea4-448b-bb60-45e4fd3ffd04', instmt='GOOG', trade_price=1136.69, trade_qty=3, trade_side='SELL', trade_id='5f09d09e-605c-42f0-999d-deb12dcbf2cf')
# Randomly generated order statement 49: Order(symbol='FB', qty=1, side='SELL', type='limit', price=390.69, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=1, price=390.69, side='SELL', timestamp='2023-03-11T21:41:33.333603', order_id='3aa203a6-3fdd-4080-8293-0000ec0b47b6', instmt='FB', trade_price=390.69, trade_qty=1, trade_side='SELL', trade_id='a7281d65-5bf1-405c-b319-e056bb789071')
# Randomly generated order statement 50: Order(symbol='AAPL', qty=5, side='SELL', type='limit', price=155.35, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=5, price=155.35, side='SELL', timestamp='2023-03-11T21:41:33.338220', order_id='af2636eb-cb48-461a-8990-cbabf18da04a', instmt='AAPL', trade_price=155.35, trade_qty=5, trade_side='SELL', trade_id='ca31ce2e-4e15-4420-9a37-e841b04d05d3')
# Randomly generated order statement 51: Order(symbol='GOOG', qty=3, side='SELL', type='limit', price=1111.82, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1111.82, side='SELL', timestamp='2023-03-11T21:41:33.343909', order_id='428ce8c6-0ad1-45e3-a8e7-421b4c5d6484', instmt='GOOG', trade_price=1111.82, trade_qty=3, trade_side='SELL', trade_id='f377b511-00f6-43b4-a8e5-f6c7aa9a326b')
# Randomly generated order statement 52: Order(symbol='GOOG', qty=8, side='BUY', type='limit', price=1185.87, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=8, price=1185.87, side='BUY', timestamp='2023-03-11T21:41:33.351407', order_id='fe7c88af-5856-466d-9baf-d99132965782', instmt='GOOG', trade_price=1185.87, trade_qty=8, trade_side='BUY', trade_id='54001cfd-6f12-462b-a146-4ffffedcbd69')
# Randomly generated order statement 53: Order(symbol='GOOG', qty=4, side='SELL', type='limit', price=1156.75, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=4, price=1156.75, side='SELL', timestamp='2023-03-11T21:41:33.358816', order_id='f5bb6c07-b4bd-4db9-919f-694b2c878a29', instmt='GOOG', trade_price=1156.75, trade_qty=4, trade_side='SELL', trade_id='28174dde-ba75-450a-824f-2366b63fce5a')
# Randomly generated order statement 54: Order(symbol='GOOG', qty=8, side='BUY', type='limit', price=1183.44, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=8, price=1183.44, side='BUY', timestamp='2023-03-11T21:41:33.364050', order_id='b4cbd04d-2b0f-43c8-8155-4d3f0c4736a1', instmt='GOOG', trade_price=1183.44, trade_qty=8, trade_side='BUY', trade_id='8ca5d5bc-96a2-448f-a22d-ef432d9b9e84')
# Randomly generated order statement 55: Order(symbol='AAPL', qty=3, side='BUY', type='limit', price=167.83, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=3, price=167.83, side='BUY', timestamp='2023-03-11T21:41:33.370266', order_id='755266f6-cc55-4a84-b612-c6c41481fb8d', instmt='AAPL', trade_price=167.83, trade_qty=3, trade_side='BUY', trade_id='92570ccd-f81d-4800-ae7b-2bccaea240fe')
# Randomly generated order statement 56: Order(symbol='AAPL', qty=3, side='BUY', type='limit', price=161.14, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=3, price=161.14, side='BUY', timestamp='2023-03-11T21:41:33.376274', order_id='aaa0a30c-4cf3-497f-a898-3aa4b9571935', instmt='AAPL', trade_price=161.14, trade_qty=3, trade_side='BUY', trade_id='6a9bc058-0b5b-4959-b00e-73ed75957173')
# Randomly generated order statement 57: Order(symbol='TSLA', qty=3, side='SELL', type='limit', price=732.16, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=3, price=732.16, side='SELL', timestamp='2023-03-11T21:41:33.383197', order_id='e656806a-2f87-4f06-a9b8-be7b8841ce72', instmt='TSLA', trade_price=732.16, trade_qty=3, trade_side='SELL', trade_id='1f85e8a4-cd31-41e4-8bc2-e42436f22de3')
# Randomly generated order statement 58: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1135.83, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1135.83, side='SELL', timestamp='2023-03-11T21:41:33.389503', order_id='18811d41-bee7-4ea7-b1d4-cdbe5bcf0fc3', instmt='GOOG', trade_price=1135.83, trade_qty=7, trade_side='SELL', trade_id='197819cc-48b7-490f-aacb-d8553612e5a8')
# Randomly generated order statement 59: Order(symbol='AAPL', qty=8, side='SELL', type='limit', price=153.37, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=8, price=153.37, side='SELL', timestamp='2023-03-11T21:41:33.395461', order_id='a59dcbcf-2bb2-4d53-99a2-9f1182be4c09', instmt='AAPL', trade_price=153.37, trade_qty=8, trade_side='SELL', trade_id='b5abb4b7-5783-477c-93ee-55a7865e2b69')
# Randomly generated order statement 60: Order(symbol='FB', qty=8, side='BUY', type='limit', price=408.46, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=8, price=408.46, side='BUY', timestamp='2023-03-11T21:41:33.400951', order_id='be0db03f-f27b-490d-a3c7-d4a2a5a7174e', instmt='FB', trade_price=408.46, trade_qty=8, trade_side='BUY', trade_id='97bedf48-2661-4f1b-901b-004edcea8c2b')
# Randomly generated order statement 61: Order(symbol='FB', qty=2, side='SELL', type='limit', price=391.71, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=2, price=391.71, side='SELL', timestamp='2023-03-11T21:41:33.406981', order_id='4b3088d2-7c0e-4c1f-9597-6ee1193f8d6c', instmt='FB', trade_price=391.71, trade_qty=2, trade_side='SELL', trade_id='005a8eee-f9b6-46a2-b1aa-6f07f25e1954')
# Randomly generated order statement 62: Order(symbol='AAPL', qty=10, side='BUY', type='limit', price=164.12, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=10, price=164.12, side='BUY', timestamp='2023-03-11T21:41:33.413030', order_id='62acbc08-c20b-483c-8763-ced4c38e51eb', instmt='AAPL', trade_price=164.12, trade_qty=10, trade_side='BUY', trade_id='9013721e-d238-482c-8bd3-8d03aea5c277')
# Randomly generated order statement 63: Order(symbol='TSLA', qty=1, side='BUY', type='limit', price=792.52, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=1, price=792.52, side='BUY', timestamp='2023-03-11T21:41:33.418768', order_id='614e9245-7744-4b53-997f-2b0ebacdbebb', instmt='TSLA', trade_price=792.52, trade_qty=1, trade_side='BUY', trade_id='dafc455f-b18d-4325-af29-48129b38de9a')
# Randomly generated order statement 64: Order(symbol='AAPL', qty=8, side='BUY', type='limit', price=165.31, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=8, price=165.31, side='BUY', timestamp='2023-03-11T21:41:33.424673', order_id='a4129487-992e-4409-9d8a-ecadd4f45268', instmt='AAPL', trade_price=165.31, trade_qty=8, trade_side='BUY', trade_id='779ad750-0056-48eb-aa0b-960f87da5fc2')
# Randomly generated order statement 65: Order(symbol='TSLA', qty=5, side='SELL', type='limit', price=724.44, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=5, price=724.44, side='SELL', timestamp='2023-03-11T21:41:33.430373', order_id='4f7dcf77-97ef-4c89-8059-8290479b405b', instmt='TSLA', trade_price=724.44, trade_qty=5, trade_side='SELL', trade_id='925e6952-7d82-4ba6-a057-61f44bc3c88b')
# Randomly generated order statement 66: Order(symbol='AMZN', qty=9, side='SELL', type='limit', price=3009.61, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=9, price=3009.61, side='SELL', timestamp='2023-03-11T21:41:33.435839', order_id='4e093d27-1cd5-4766-a3e1-21196ac48857', instmt='AMZN', trade_price=3009.61, trade_qty=9, trade_side='SELL', trade_id='1f49aa53-6b07-403d-a626-da3b46a3fc95')
# Randomly generated order statement 67: Order(symbol='AAPL', qty=5, side='BUY', type='limit', price=165.26, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=5, price=165.26, side='BUY', timestamp='2023-03-11T21:41:33.441682', order_id='1d52258b-3213-487e-9fd2-1a7508516b26', instmt='AAPL', trade_price=165.26, trade_qty=5, trade_side='BUY', trade_id='5f094d4d-d8f1-4e4d-9564-26ed51d7edc4')
# Randomly generated order statement 68: Order(symbol='GOOG', qty=8, side='SELL', type='limit', price=1158.13, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=8, price=1158.13, side='SELL', timestamp='2023-03-11T21:41:33.447544', order_id='173a4060-7c82-44eb-837a-9e3ec63efdee', instmt='GOOG', trade_price=1158.13, trade_qty=8, trade_side='SELL', trade_id='ccc5ca9a-1e1d-454b-a73a-f23306c0f9fb')
# Randomly generated order statement 69: Order(symbol='AAPL', qty=9, side='SELL', type='limit', price=157.31, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=9, price=157.31, side='SELL', timestamp='2023-03-11T21:41:33.452981', order_id='9c45a960-f22d-4526-ae89-0fc25e8a8924', instmt='AAPL', trade_price=157.31, trade_qty=9, trade_side='SELL', trade_id='a8be969f-6449-4f2e-8511-a50ce8fedf33')
# Randomly generated order statement 70: Order(symbol='AMZN', qty=1, side='BUY', type='limit', price=3020.17, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=3020.17, side='BUY', timestamp='2023-03-11T21:41:33.460206', order_id='8619d0af-ad8c-45a7-b7ce-d129af160285', instmt='AMZN', trade_price=3020.17, trade_qty=1, trade_side='BUY', trade_id='28ccb979-a51f-4bf4-a6e7-c8d9b49bd1cf')
# Randomly generated order statement 71: Order(symbol='AMZN', qty=9, side='BUY', type='limit', price=3076.66, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=9, price=3076.66, side='BUY', timestamp='2023-03-11T21:41:33.466084', order_id='abc2eb1a-61c8-4502-b59b-addf24566e12', instmt='AMZN', trade_price=3076.66, trade_qty=9, trade_side='BUY', trade_id='f1cffb1c-fc07-4d39-8da9-18e878e9ea85')
# Randomly generated order statement 72: Order(symbol='AAPL', qty=1, side='SELL', type='limit', price=154.46, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=154.46, side='SELL', timestamp='2023-03-11T21:41:33.472554', order_id='82a9b736-46e2-40a8-8f8f-c64de92c79b9', instmt='AAPL', trade_price=154.46, trade_qty=1, trade_side='SELL', trade_id='f2847c1a-c608-498d-837e-a29fa150b4c0')
# Randomly generated order statement 73: Order(symbol='AMZN', qty=4, side='SELL', type='limit', price=2899.26, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=4, price=2899.26, side='SELL', timestamp='2023-03-11T21:41:33.477871', order_id='a77c65a2-2a51-48c7-bb45-fb712ae8c840', instmt='AMZN', trade_price=2899.26, trade_qty=4, trade_side='SELL', trade_id='40cd5bfd-1b78-4187-aefc-f12ba3a96a02')
# Randomly generated order statement 74: Order(symbol='AMZN', qty=6, side='SELL', type='limit', price=2865.8, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=6, price=2865.8, side='SELL', timestamp='2023-03-11T21:41:33.483336', order_id='97b0500e-d749-4bc6-aa6d-5fda7a84ddea', instmt='AMZN', trade_price=2865.8, trade_qty=6, trade_side='SELL', trade_id='eeb612eb-8644-43ab-9e79-a61f2f69c9e9')
# Randomly generated order statement 75: Order(symbol='AAPL', qty=10, side='SELL', type='limit', price=157.33, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=10, price=157.33, side='SELL', timestamp='2023-03-11T21:41:33.489063', order_id='72f33074-f605-4f3e-b093-d243ae77ddc0', instmt='AAPL', trade_price=157.33, trade_qty=10, trade_side='SELL', trade_id='d22a7596-cfa3-4f77-833e-a0347009f151')
# Randomly generated order statement 76: Order(symbol='AMZN', qty=1, side='SELL', type='limit', price=3000.63, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=1, price=3000.63, side='SELL', timestamp='2023-03-11T21:41:33.494265', order_id='ec4ec22d-da30-4eee-9897-688716b485f1', instmt='AMZN', trade_price=3000.63, trade_qty=1, trade_side='SELL', trade_id='c7f6620a-8bca-463d-baa1-e0cdcbe1016d')
# Randomly generated order statement 77: Order(symbol='AAPL', qty=1, side='SELL', type='limit', price=152.67, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=152.67, side='SELL', timestamp='2023-03-11T21:41:33.499297', order_id='240a9de2-1b0e-493d-bc96-f1d6d1990ffe', instmt='AAPL', trade_price=152.67, trade_qty=1, trade_side='SELL', trade_id='6a3d6042-7d95-4f12-98f8-a4b6c596ed01')
# Randomly generated order statement 78: Order(symbol='TSLA', qty=10, side='SELL', type='limit', price=752.65, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=10, price=752.65, side='SELL', timestamp='2023-03-11T21:41:33.504550', order_id='52df2519-b276-4d1d-8721-51e65611d4a6', instmt='TSLA', trade_price=752.65, trade_qty=10, trade_side='SELL', trade_id='a4592217-48ee-4078-aaa3-575d17db4e99')
# Randomly generated order statement 79: Order(symbol='AAPL', qty=10, side='SELL', type='limit', price=153.04, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=10, price=153.04, side='SELL', timestamp='2023-03-11T21:41:33.510279', order_id='5de8d4c2-8027-48ac-bca6-48b840959587', instmt='AAPL', trade_price=153.04, trade_qty=10, trade_side='SELL', trade_id='62dac58c-54bd-46f4-a9d6-d9038961f387')
# Randomly generated order statement 80: Order(symbol='FB', qty=7, side='SELL', type='limit', price=379.13, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=7, price=379.13, side='SELL', timestamp='2023-03-11T21:41:33.515890', order_id='8eddc1e5-1fdd-4547-980c-2c6539486247', instmt='FB', trade_price=379.13, trade_qty=7, trade_side='SELL', trade_id='c64b6551-f5a9-4211-b780-47529ee4c379')
# Randomly generated order statement 81: Order(symbol='FB', qty=10, side='BUY', type='limit', price=412.54, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=10, price=412.54, side='BUY', timestamp='2023-03-11T21:41:33.520832', order_id='5f05ad7c-bd78-4289-8fb8-53f3322c75d7', instmt='FB', trade_price=412.54, trade_qty=10, trade_side='BUY', trade_id='a75be624-a3fd-4811-92f6-90eebc62053f')
# Randomly generated order statement 82: Order(symbol='GOOG', qty=2, side='BUY', type='limit', price=1215.73, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=2, price=1215.73, side='BUY', timestamp='2023-03-11T21:41:33.526426', order_id='3407018f-f353-4f9c-8af5-4a8171fef180', instmt='GOOG', trade_price=1215.73, trade_qty=2, trade_side='BUY', trade_id='fac9eca9-eba7-4ef3-94a1-0a58749fe925')
# Randomly generated order statement 83: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1150.51, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1150.51, side='SELL', timestamp='2023-03-11T21:41:33.531602', order_id='886106cd-d3cd-494b-a04a-b063081dc6c5', instmt='GOOG', trade_price=1150.51, trade_qty=7, trade_side='SELL', trade_id='fc5f67c9-b1d5-4e32-8315-80fd5bdbbae3')
# Randomly generated order statement 84: Order(symbol='AAPL', qty=2, side='BUY', type='limit', price=167.25, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=167.25, side='BUY', timestamp='2023-03-11T21:41:33.537666', order_id='35afe55d-83cc-4d75-8574-dfc9ed0496e5', instmt='AAPL', trade_price=167.25, trade_qty=2, trade_side='BUY', trade_id='cab8f68b-7de8-4141-9e1b-fc625497b405')
# Randomly generated order statement 85: Order(symbol='AAPL', qty=1, side='SELL', type='limit', price=156.7, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=1, price=156.7, side='SELL', timestamp='2023-03-11T21:41:33.543851', order_id='036a2157-e285-41b6-829f-46cc4242f542', instmt='AAPL', trade_price=156.7, trade_qty=1, trade_side='SELL', trade_id='ee4edba3-d7c2-410a-8eb2-7e82f3f76d22')
# Randomly generated order statement 86: Order(symbol='AAPL', qty=2, side='BUY', type='limit', price=160.54, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=2, price=160.54, side='BUY', timestamp='2023-03-11T21:41:33.550382', order_id='d4d8f87b-e7aa-4f20-9596-d696ec9d8e7a', instmt='AAPL', trade_price=160.54, trade_qty=2, trade_side='BUY', trade_id='0183205c-87e6-423c-a53b-7c909e7e8bca')
# Randomly generated order statement 87: Order(symbol='GOOG', qty=7, side='SELL', type='limit', price=1120.19, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=7, price=1120.19, side='SELL', timestamp='2023-03-11T21:41:33.558070', order_id='4a14a6ac-6296-4101-a1a2-8d91a2428163', instmt='GOOG', trade_price=1120.19, trade_qty=7, trade_side='SELL', trade_id='915d20f2-9d08-4ac0-8e40-662f80842281')
# Randomly generated order statement 88: Order(symbol='GOOG', qty=3, side='BUY', type='limit', price=1220.76, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=3, price=1220.76, side='BUY', timestamp='2023-03-11T21:41:33.565258', order_id='8c6ba89e-75f5-4820-9f9f-93db03164f30', instmt='GOOG', trade_price=1220.76, trade_qty=3, trade_side='BUY', trade_id='4d076907-813d-4d50-82d1-8e00d4ab8cbd')
# Randomly generated order statement 89: Order(symbol='GOOG', qty=1, side='SELL', type='limit', price=1126.81, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=1, price=1126.81, side='SELL', timestamp='2023-03-11T21:41:33.571644', order_id='507f93a3-78c7-4c5f-b6a9-6429c4adcd63', instmt='GOOG', trade_price=1126.81, trade_qty=1, trade_side='SELL', trade_id='53f93efc-bd60-403d-93ad-c3df32f0de86')
# Randomly generated order statement 90: Order(symbol='FB', qty=8, side='BUY', type='limit', price=408.37, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=8, price=408.37, side='BUY', timestamp='2023-03-11T21:41:33.577861', order_id='37083f33-a9e3-4330-b888-d344fa50085e', instmt='FB', trade_price=408.37, trade_qty=8, trade_side='BUY', trade_id='79f7f8bd-47e5-464f-b8e1-7a30908ce63c')
# Randomly generated order statement 91: Order(symbol='FB', qty=4, side='SELL', type='limit', price=378.87, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='FB', qty=4, price=378.87, side='SELL', timestamp='2023-03-11T21:41:33.583538', order_id='80aaa39d-8c0a-413b-93d2-c21fc12a61ad', instmt='FB', trade_price=378.87, trade_qty=4, trade_side='SELL', trade_id='b0c9a9b1-f8d9-44ae-8910-80729d77d299')
# Randomly generated order statement 92: Order(symbol='TSLA', qty=5, side='BUY', type='limit', price=775.63, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=5, price=775.63, side='BUY', timestamp='2023-03-11T21:41:33.589007', order_id='3519c380-9b19-471f-ae48-f9c5066f9546', instmt='TSLA', trade_price=775.63, trade_qty=5, trade_side='BUY', trade_id='7777e7fa-b49f-4694-b77c-1e4bf60930eb')
# Randomly generated order statement 93: Order(symbol='AMZN', qty=3, side='BUY', type='limit', price=3036.79, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=3, price=3036.79, side='BUY', timestamp='2023-03-11T21:41:33.594790', order_id='d43c8af0-0158-4b0d-acd0-4d67dd44e980', instmt='AMZN', trade_price=3036.79, trade_qty=3, trade_side='BUY', trade_id='e7ee5168-0502-467c-a1ca-993a8d7dbf8d')
# Randomly generated order statement 94: Order(symbol='AMZN', qty=5, side='SELL', type='limit', price=2881.72, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=5, price=2881.72, side='SELL', timestamp='2023-03-11T21:41:33.600728', order_id='8b8b5d5d-d0ac-4399-a2f5-3a98a6a0bddb', instmt='AMZN', trade_price=2881.72, trade_qty=5, trade_side='SELL', trade_id='22cb8797-142d-486d-b17c-73dd9c096d2c')
# Randomly generated order statement 95: Order(symbol='GOOG', qty=8, side='BUY', type='limit', price=1171.53, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='GOOG', qty=8, price=1171.53, side='BUY', timestamp='2023-03-11T21:41:33.605805', order_id='33d34d1b-853e-401a-ae07-ca183dc05581', instmt='GOOG', trade_price=1171.53, trade_qty=8, trade_side='BUY', trade_id='8bcb2e03-ff9d-4358-921a-6fd7b932cb5e')
# Randomly generated order statement 96: Order(symbol='AAPL', qty=3, side='SELL', type='limit', price=153.08, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AAPL', qty=3, price=153.08, side='SELL', timestamp='2023-03-11T21:41:33.611641', order_id='4707dd5c-4205-4e50-8ebb-de8c71f23dba', instmt='AAPL', trade_price=153.08, trade_qty=3, trade_side='SELL', trade_id='3d75c42b-4a4a-41c6-9074-d54c8b31dcc1')
# Randomly generated order statement 97: Order(symbol='AMZN', qty=2, side='SELL', type='limit', price=2897.23, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=2, price=2897.23, side='SELL', timestamp='2023-03-11T21:41:33.616666', order_id='422379d1-caf7-4013-a29a-794037a30806', instmt='AMZN', trade_price=2897.23, trade_qty=2, trade_side='SELL', trade_id='ffe0739c-4e8e-435e-b1c7-7705ad94a9c5')
# Randomly generated order statement 98: Order(symbol='TSLA', qty=9, side='SELL', type='limit', price=758.34, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=9, price=758.34, side='SELL', timestamp='2023-03-11T21:41:33.621648', order_id='5267adc6-bdc2-4526-b77d-637093e744a2', instmt='TSLA', trade_price=758.34, trade_qty=9, trade_side='SELL', trade_id='64c2a7ff-af29-464a-a27b-c61ca3525157')
# Randomly generated order statement 99: Order(symbol='AMZN', qty=8, side='SELL', type='limit', price=2979.19, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='AMZN', qty=8, price=2979.19, side='SELL', timestamp='2023-03-11T21:41:33.627140', order_id='271c9d02-f66c-43cd-ba57-f4863de34cef', instmt='AMZN', trade_price=2979.19, trade_qty=8, trade_side='SELL', trade_id='e104d752-9e74-4117-a016-26f431b719ee')
# Randomly generated order statement 100: Order(symbol='TSLA', qty=9, side='SELL', type='limit', price=733.68, time_in_force='2023-03-11 16:41:33')
# Order Placed Successfully
# Trade(symbol='TSLA', qty=9, price=733.68, side='SELL', timestamp='2023-03-11T21:41:33.632432', order_id='ea97594b-6a7f-4049-b274-664565c1c773', instmt='TSLA', trade_price=733.68, trade_qty=9, trade_side='SELL', trade_id='689feb87-755c-40a9-84ed-81090eb66a3d')
